# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL du site
base_url = "https://www.digischool.fr"

# URLs par établissement
urls_depart = [
    "https://www.digischool.fr/primaire",
    "https://www.digischool.fr/college",
    "https://www.digischool.fr/lycee"
]

def get_links(url : str, prefix : str) -> list:
    """
    Fonction pour récupérer les liens des cours.

    Args:
        url (str): URL de la page.
        prefix (str): Préfixe des liens des cours.
    
    Returns:
        list: Liste des liens des cours.
    """

    # Récupération de la réponse de la requête
    response = requests.get(url)
    liens = []

    # Si la réponse est 200, on parse le contenu de la page pour récupérer les liens des cours pour un niveau donné
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        balises_a = soup.find_all('a', href=True)
        liens_filtres = [a['href'] for a in balises_a if a['href'].startswith(prefix)]
        liens_complets = [base_url + lien for lien in liens_filtres]
        liens.extend(liens_complets)
    return liens

def get_lesson(url : str, cours_data : str):
    """
    Fonction pour récupérer le contenu des cours.

    Args:
        url (str): URL de la page.
        cours_data (list): Liste pour stocker les données des cours.
    """

    # Récupération de la réponse de la requête
    response = requests.get(url)

    # Si la réponse est 200, on parse le contenu de la page pour récupérer les liens des cours d'une matière donnée
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        balises_a = soup.find_all('a', href=True)
        liens_cours = [a['href'] for a in balises_a if a['href'].startswith('/cours/')]
        liens_complets = ["https://www.digischool.fr" + lien for lien in liens_cours]
        
        for lien in liens_complets:
            # Extraction du nom du cours
            partie_cours = lien.split('/cours/')[1]
            nom_cours = partie_cours.split('?')[0].replace('-', ' ')
            
            # Extraction du nom du chapitre
            if '%2C' in lien:
                nom_chapitre = lien.split('%2C')[-1].replace('-', ' ')
            else:
                nom_chapitre = "N/A"
            
            # Extraction du nom de la matière et du niveau
            parties = lien.split('%2C')
            if len(parties) >= 3:
                nom_matiere = parties[-2].replace('-', ' ')
                niveau = parties[-3].replace('-', ' ')
            else:
                nom_matiere = "N/A"
                niveau = "N/A"
            
            # Récupération de la réponse de la requête
            second_response = requests.get(lien)
            
            # Si la réponse est 200, on parse le contenu de la page pour récupérer le contenu des cours
            if second_response.status_code == 200:
                second_soup = BeautifulSoup(second_response.text, 'html.parser')
                span_latex = second_soup.find('span', class_='__Latex__')
                if span_latex:
                    article = span_latex.find_parent('article')
                    if article:
                        texte_nettoye = article.get_text(separator=' ', strip=True)
                    else:
                        texte_nettoye = "Balise </article> non trouvée."
                else:
                    texte_nettoye = "Balise <span class=\"__Latex__\"> non trouvée."
            else:
                texte_nettoye = "Erreur lors de la récupération de la page."
            
            # Stockage des informations
            cours_info = {
                "lien": lien,
                "nom_du_cours": nom_cours,
                "nom_du_chapitre": nom_chapitre,
                "nom_de_la_matiere": nom_matiere,
                "niveau": niveau,
                "texte": texte_nettoye
            }
            
            cours_data.append(cours_info)
        
        # Mise en forme des informations
        if len(liens_cours) > 0:
            exemple_lien = liens_cours[0]
            parties_exemple = exemple_lien.split('%2C')
            if len(parties_exemple) >= 3:
                nom_matiere_ex = parties_exemple[-2].replace('-', ' ')
                niveau_ex = parties_exemple[-3].replace('-', ' ')
            else:
                nom_matiere_ex = "N/A"
                niveau_ex = "N/A"
            print(f"[INFO] Tous les cours de '{nom_matiere_ex}' de niveau '{niveau_ex}' ont été récupérés.")
    else:
        print("Erreur lors de la récupération de la page.")

def main():
    """
    Fonction principale.
    """

    # Définition de la structure des liens
    toutes_les_pages = []
    for url in urls_depart:
        if '/primaire' in url:
            prefix = '/primaire/'
        elif '/college' in url:
            prefix = '/college/'
        elif '/lycee' in url:
            prefix = '/lycee/'
        else:
            prefix = '/'
        liens = get_links(url, prefix)
        toutes_les_pages.extend(liens)
    
    # Traitement spécial pour les cours de première et terminale
    sous_categories = [lien for lien in toutes_les_pages if '/lycee/premiere' in lien or '/lycee/terminale' in lien]
    for sous_url in sous_categories:
        path_relatif = sous_url.replace(base_url, '')
        sous_prefix = path_relatif + '/'
        sous_liens = get_links(sous_url, sous_prefix)
        toutes_les_pages.extend(sous_liens)

    # Suppression des doublons
    toutes_les_pages = list(set(toutes_les_pages))

    cours_data = []

    # Itération sur les pages pour récupérer les cours
    for page in toutes_les_pages:
        get_lesson(page, cours_data)
    
    # Conversion des données en DataFrame et exportation en CSV
    df = pd.DataFrame(cours_data)
    df.to_csv('cours.csv', index=False, sep="|", encoding="utf-8")
    print("[FINISH] Les données ont été exportées dans 'cours.csv'.")

if __name__ == "__main__":
    main()
# Out:
# [INFO] Tous les cours de 'questionner le monde' de niveau 'ce1' ont été récupérés.
# [INFO] Tous les cours de 'stss' de niveau 'premiere st2s' ont été récupérés.
# [INFO] Tous les cours de 'maitriser ton identite numerique' de niveau 'premiere stl' ont été récupérés.
# [INFO] Tous les cours de 'espagnol' de niveau 'premiere st2s' ont été récupérés.
# [INFO] Tous les cours de 'histoire geographie emc' de niveau 'troisieme' ont été récupérés.
# [INFO] Tous les cours de 'ses' de niveau 'seconde' ont été récupérés.
# [INFO] Tous les cours de 'hggsp' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'espagnol' de niveau 'terminale stl' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'svt' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'enseignement scientifique' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'cm1' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'cm2' ont été récupérés.
# [INFO] Tous les cours de 'histoire geographie' de niveau 'seconde' ont été récupérés.
# [INFO] Tous les cours de 'numerique et sciences informatiques' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'philosophie programme' de niveau 'terminale st2s' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'quatrieme' ont été récupérés.
# [INFO] Tous les cours de 'physique chimie' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'premiere st2s' ont été récupérés.
# [INFO] Tous les cours de 'italien' de niveau 'terminale st2s' ont été récupérés.
# [INFO] Tous les cours de 'histoire des arts' de niveau 'troisieme' ont été récupérés.
# [INFO] Tous les cours de 'allemand' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'philosophie' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'bac pro' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'seconde' ont été récupérés.
# [INFO] Tous les cours de 'technologie' de niveau 'troisieme' ont été récupérés.
# [INFO] Tous les cours de 'stage' de niveau 'troisieme' ont été récupérés.
# [INFO] Tous les cours de 'svt' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'terminale stl' ont été récupérés.
# [INFO] Tous les cours de 'physique chimie mathematiques' de niveau 'terminale stl' ont été récupérés.
# [INFO] Tous les cours de 'epi' de niveau 'troisieme' ont été récupérés.
# [INFO] Tous les cours de 'llce anglais' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'hlp' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'sciences gestion numerique' de niveau 'premiere stmg' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques programme' de niveau 'terminale sti2d' ont été récupérés.
# [INFO] Tous les cours de 'italien' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'espagnol' de niveau 'terminale sti2d' ont été récupérés.
# [INFO] Tous les cours de 'svt' de niveau 'quatrieme' ont été récupérés.
# [INFO] Tous les cours de 'eco droit' de niveau 'bac pro' ont été récupérés.
# [INFO] Tous les cours de 'italien' de niveau 'premiere st2s' ont été récupérés.
# [INFO] Tous les cours de 'italien' de niveau 'terminale stl' ont été récupérés.
# [INFO] Tous les cours de 'allemand' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'svt' de niveau 'cinquieme' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'sixieme' ont été récupérés.
# [INFO] Tous les cours de 'histoire geographie programme' de niveau 'terminale stl' ont été récupérés.
# [INFO] Tous les cours de 'droit economie' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'sciences technologie' de niveau 'cm2' ont été récupérés.
# [INFO] Tous les cours de 'histoire' de niveau 'cm2' ont été récupérés.
# [INFO] Tous les cours de 'numerique et sciences informatiques' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'svt' de niveau 'troisieme' ont été récupérés.
# [INFO] Tous les cours de 'svt' de niveau 'seconde' ont été récupérés.
# [INFO] Tous les cours de 'allemand' de niveau 'premiere sti2d' ont été récupérés.
# [INFO] Tous les cours de 'histoire geographie' de niveau 'premiere stl' ont été récupérés.
# [INFO] Tous les cours de 'physique chimie' de niveau 'bac pro' ont été récupérés.
# [INFO] Tous les cours de 'eco gestion' de niveau 'bac pro' ont été récupérés.
# [INFO] Tous les cours de 'enseignement scientifique' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'bph' de niveau 'premiere st2s' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'troisieme' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'premiere st2s' ont été récupérés.
# [INFO] Tous les cours de 'philosophie programme' de niveau 'terminale sti2d' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'premiere stl' ont été récupérés.
# [INFO] Tous les cours de 'questionner le monde' de niveau 'ce2' ont été récupérés.
# [INFO] Tous les cours de 'ses' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'allemand' de niveau 'terminale st2s' ont été récupérés.
# [INFO] Tous les cours de 'italien' de niveau 'premiere stl' ont été récupérés.
# [INFO] Tous les cours de 'histoire geographie' de niveau 'cinquieme' ont été récupérés.
# [INFO] Tous les cours de 'gestion et finance' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'management' de niveau 'premiere stmg' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'cp' ont été récupérés.
# [INFO] Tous les cours de 'histoire geo' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'cm2' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'cinquieme' ont été récupérés.
# [INFO] Tous les cours de 'physique chimie' de niveau 'cinquieme' ont été récupérés.
# [INFO] Tous les cours de 'emc' de niveau 'cp' ont été récupérés.
# [INFO] Tous les cours de 'pcm' de niveau 'premiere stl' ont été récupérés.
# [INFO] Tous les cours de 'histoire' de niveau 'cm1' ont été récupérés.
# [INFO] Tous les cours de 'allemand' de niveau 'terminale stl' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'terminale st2s' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'premiere sti2d' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'sixieme' ont été récupérés.
# [INFO] Tous les cours de 'maitriser ton identite numerique' de niveau 'terminale st2s' ont été récupérés.
# [INFO] Tous les cours de 'emc' de niveau 'ce2' ont été récupérés.
# [INFO] Tous les cours de 'eco droit' de niveau 'premiere stmg' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'ce2' ont été récupérés.
# [INFO] Tous les cours de 'pse' de niveau 'bac pro' ont été récupérés.
# [INFO] Tous les cours de 'ses' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'maths complementaires' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'physique chimie mathematiques' de niveau 'terminale sti2d' ont été récupérés.
# [INFO] Tous les cours de 'physique chimie' de niveau 'seconde' ont été récupérés.
# [INFO] Tous les cours de 'histoire geographie programme' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'hggsp' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'ce2' ont été récupérés.
# [INFO] Tous les cours de 'italien' de niveau 'premiere stmg' ont été récupérés.
# [INFO] Tous les cours de 'histoire geo emc' de niveau 'sixieme' ont été récupérés.
# [INFO] Tous les cours de 'histoire geo' de niveau 'bac pro' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'premiere sti2d' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'quatrieme' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'premiere sti2d' ont été récupérés.
# [INFO] Tous les cours de 'allemand' de niveau 'premiere stl' ont été récupérés.
# [INFO] Tous les cours de 'espagnol' de niveau 'premiere stl' ont été récupérés.
# [INFO] Tous les cours de 'physique chimie' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'espagnol' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'sig enseignement specifique' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'cp' ont été récupérés.
# [INFO] Tous les cours de 'physique chimie' de niveau 'troisieme' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'seconde' ont été récupérés.
# [INFO] Tous les cours de 'espagnol' de niveau 'premiere stmg' ont été récupérés.
# [INFO] Tous les cours de 'management sciences gestion numerique' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'pcm' de niveau 'premiere sti2d' ont été récupérés.
# [INFO] Tous les cours de 'italien' de niveau 'terminale sti2d' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'premiere stmg' ont été récupérés.
# [INFO] Tous les cours de 'philosophie programme' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'histoire geographie' de niveau 'quatrieme' ont été récupérés.
# [INFO] Tous les cours de 'spe mathematiques' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'premiere st2s' ont été récupérés.
# [INFO] Tous les cours de 'questionner le monde' de niveau 'cp' ont été récupérés.
# [INFO] Tous les cours de 'pcs' de niveau 'premiere st2s' ont été récupérés.
# [INFO] Tous les cours de 'allemand' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'geographie' de niveau 'cm1' ont été récupérés.
# [INFO] Tous les cours de 'grand oral' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'cinquieme' ont été récupérés.
# [INFO] Tous les cours de 'sciences numerique technologie' de niveau 'seconde' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'quatrieme' ont été récupérés.
# [INFO] Tous les cours de 'sciences' de niveau 'sixieme' ont été récupérés.
# [INFO] Tous les cours de 'philosophie programme' de niveau 'terminale stl' ont été récupérés.
# [INFO] Tous les cours de 'maitriser ton identite numerique' de niveau 'premiere sti2d' ont été récupérés.
# [INFO] Tous les cours de 'maitriser ton identite numerique' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'ce1' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'terminale sti2d' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'emc' de niveau 'cm2' ont été récupérés.
# [INFO] Tous les cours de 'maitriser ton identite numerique' de niveau 'premiere stmg' ont été récupérés.
# [INFO] Tous les cours de 'rhc enseignement specifique' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'maitriser ton identite numerique' de niveau 'terminale stl' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'troisieme' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'cinquieme' ont été récupérés.
# [INFO] Tous les cours de 'geographie' de niveau 'cm2' ont été récupérés.
# [INFO] Tous les cours de 'mercatique enseignement specifique' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'espagnol' de niveau 'premiere sti2d' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'troisieme' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques programme' de niveau 'terminale st2s' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques programme' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'histoire geographie programme' de niveau 'terminale sti2d' ont été récupérés.
# [INFO] Tous les cours de 'grand oral' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'maitriser ton identite numerique' de niveau 'terminale sti2d' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'chimie bph' de niveau 'terminale st2s' ont été récupérés.
# [INFO] Tous les cours de 'espagnol' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'epreuve orale' de niveau 'troisieme' ont été récupérés.
# [INFO] Tous les cours de 'histoire geographie' de niveau 'premiere sti2d' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'bac pro' ont été récupérés.
# [INFO] Tous les cours de 'histoire geographie' de niveau 'premiere st2s' ont été récupérés.
# [INFO] Tous les cours de 'spe mathematiques' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'hlp' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques expertes' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'premiere stmg' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'terminale stmg' ont été récupérés.
# [INFO] Tous les cours de 'histoire geographie' de niveau 'premiere stmg' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques programme' de niveau 'terminale stl' ont été récupérés.
# [INFO] Tous les cours de 'sciences technologie' de niveau 'cm1' ont été récupérés.
# [INFO] Tous les cours de 'italien' de niveau 'premiere sti2d' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'ce1' ont été récupérés.
# [INFO] Tous les cours de 'emc' de niveau 'cm1' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'bac pro' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'sixieme' ont été récupérés.
# [INFO] Tous les cours de 'sciences techniques sanitaires sociales' de niveau 'terminale st2s' ont été récupérés.
# [INFO] Tous les cours de 'histoire geo' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'anglais' de niveau 'premiere stmg' ont été récupérés.
# [INFO] Tous les cours de 'allemand' de niveau 'terminale sti2d' ont été récupérés.
# [INFO] Tous les cours de 'allemand' de niveau 'premiere stmg' ont été récupérés.
# [INFO] Tous les cours de 'espagnol' de niveau 'terminale st2s' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'premiere stl' ont été récupérés.
# [INFO] Tous les cours de 'physique chimie' de niveau 'quatrieme' ont été récupérés.
# [INFO] Tous les cours de 'francais' de niveau 'premiere stl' ont été récupérés.
# [INFO] Tous les cours de 'histoire geographie programme' de niveau 'terminale st2s' ont été récupérés.
# [INFO] Tous les cours de 'espagnol' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'mathematiques' de niveau 'cm1' ont été récupérés.
# [INFO] Tous les cours de 'allemand' de niveau 'premiere st2s' ont été récupérés.
# [INFO] Tous les cours de 'italien' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'maitriser ton identite numerique' de niveau 'premiere generale' ont été récupérés.
# [INFO] Tous les cours de 'italien' de niveau 'terminale generale' ont été récupérés.
# [INFO] Tous les cours de 'emc' de niveau 'ce1' ont été récupérés.
# [INFO] Tous les cours de 'maitriser ton identite numerique' de niveau 'premiere st2s' ont été récupérés.
# [FINISH] Les données ont été exportées dans 'cours.csv'.
