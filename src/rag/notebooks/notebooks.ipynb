# %% [markdown]
# # **Packages**

# %%
import pandas as pd
import os
import sys
import google.generativeai as genai
from mistralai.client import MistralClient

sys.path.append(os.path.dirname(os.path.dirname(os.getcwd())))

from llm.database.vector_store import VectorStore
from llm.rag.rag_retriever import RagRetriever
from llm.embedding.mistral_embedding import MistralEmbedding
from llm.embedding.gemini_embedding import GoogleEmbedding
from llm.models.model_api import MultiModelLLM 



# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # **Database**

# %%
# Creer une instance de la classe VectorStore
vector_store = VectorStore(chemin_persistance='../ChromaDB')

# %%
# Ajouter des documents avec des métadonnées
documents = [
        "Le machine learning est un domaine fascinant de l'intelligence artificielle.",
        "Python est un langage de programmation très populaire pour le data science.",
        "Les réseaux de neurones permettent de résoudre des problèmes complexes."
]

metadonnees = [
        {"theme": "IA", "categorie": "technique"},
        {"theme": "Programmation", "categorie": "langage"},
        {"theme": "IA", "categorie": "technique"}
]
vector_store.ajouter_documents(documents, metadonnees)
# Out:
# Add of existing embedding ID: doc_0
# Add of existing embedding ID: doc_1
# Add of existing embedding ID: doc_2
# Add of existing embedding ID: doc_0
# Add of existing embedding ID: doc_1
# Add of existing embedding ID: doc_2
# Add of existing embedding ID: doc_0
# Add of existing embedding ID: doc_1
# Add of existing embedding ID: doc_2
# Add of existing embedding ID: doc_0
# Add of existing embedding ID: doc_1
# Add of existing embedding ID: doc_2
# Add of existing embedding ID: doc_0
# Add of existing embedding ID: doc_1
# Add of existing embedding ID: doc_2
# Add of existing embedding ID: doc_0
# Add of existing embedding ID: doc_1
# Add of existing embedding ID: doc_2
# Add of existing embedding ID: doc_0
# Add of existing embedding ID: doc_1
# Add of existing embedding ID: doc_2
# Add of existing embedding ID: doc_0
# Add of existing embedding ID: doc_1
# Add of existing embedding ID: doc_2
# Add of existing embedding ID: doc_0
# Add of existing embedding ID: doc_1
# Add of existing embedding ID: doc_2
# Add of existing embedding ID: doc_0
# Add of existing embedding ID: doc_1
# Add of existing embedding ID: doc_2
# Add of existing embedding ID: doc_0
# Add of existing embedding ID: doc_1
# Add of existing embedding ID: doc_2
# Insert of existing embedding ID: doc_0
# Insert of existing embedding ID: doc_1
# Insert of existing embedding ID: doc_2

# %%
# Vérifier les statistiques de la collection
statistiques = vector_store.obtenir_statistiques_collection()
print("Statistiques de la collection :", statistiques)
# Out:
# Statistiques de la collection : {'nombre': 3, 'nom': 'collection_par_defaut'}

# %%
# Rechercher un document
requete = "IA?"
resultats_recherche = vector_store.rechercher(requete)
print("Résultats de la recherche :", resultats_recherche)
# Out:
# Résultats de la recherche : {'documents': [["Le machine learning est un domaine fascinant de l'intelligence artificielle.", 'Les réseaux de neurones permettent de résoudre des problèmes complexes.', 'Python est un langage de programmation très populaire pour le data science.']], 'metadonnees': [[{'categorie': 'technique', 'theme': 'IA'}, {'categorie': 'technique', 'theme': 'IA'}, {'categorie': 'langage', 'theme': 'Programmation'}]], 'distances': [[0.9396867181662878, 0.9592812068120781, 1.0597596680305348]]}

# %% [markdown]
# # **Embedding**

# %% [markdown]
# ### **Mistral Embedding**

# %%
# Initialiser l'embedder avec la clé API (remplace avec ta vraie clé API)
MISTRAL_API_KEY= ""
embedding_mistral = MistralEmbedding(api_key=MISTRAL_API_KEY)

# %%
# Test de l'embedder pour un texte unique
texts = "La relativité restreinte est une théorie physique."
resultat_embedding = embedding_mistral.embed_text(texts)
print("Embedding du texte :", resultat_embedding)
# Out:
# Embedding du texte : [-0.02671814  0.0317688   0.05526733 ... -0.03814697 -0.0003984
#   0.00220871]

# %%
# Test de l'embedder pour un lot de textes
texts_batch = ["La gravité est une force fondamentale.", "Les trous noirs sont des objets fascinants."]
embeddings_batch = embedding_mistral.embed_batch(texts_batch)
print("Embeddings des textes :", embeddings_batch[0])
# Out:
# Embeddings des textes : [-0.03286743  0.00582504  0.05050659 ... -0.03004456  0.02359009
#   0.01821899]

# %% [markdown]
# ### **Gemini Embedding**

# %%
# Initialiser l'embedding de la classe avec la clé API Google
GEMINI_API_KEY=""
embedding_gemini = GoogleEmbedding(GEMINI_API_KEY)

# %%
# Texte à convertir en embedding
text = "L'intelligence artificielle transforme le monde."

# Génération de l'embedding
embedding = await embedding_gemini.embed_text(text)

# Affichage de l'embedding
print("Embedding du texte :")
print(embedding)
# Out:
# Embedding du texte :
# [ 2.64508330e-02  2.60165200e-03 -6.53941900e-02  1.04939810e-02
#   7.38353950e-02  2.89325270e-02  3.43765800e-02 -6.66481950e-03
#   5.55513330e-03  6.52885600e-02  1.98605700e-02  2.44632750e-02
#  -1.10129975e-02  1.56161000e-02  8.20511300e-03 -3.27631700e-02
#   1.22307990e-02  5.33484630e-02  1.27895660e-02 -1.03109740e-02
#  -4.19059070e-03  1.64422240e-02 -1.48007300e-02 -1.71111620e-02
#   2.48462100e-02 -4.03089860e-02  3.26090050e-02 -3.86583660e-02
#  -2.73238330e-02  1.00494250e-02 -3.18987630e-02  1.20524680e-02
#  -3.73537900e-02  3.77284000e-03  2.22064600e-02 -3.90822700e-02
#   5.83823900e-03  3.07914600e-02  1.38041710e-02 -2.65148360e-02
#   1.67768630e-02 -5.78036940e-02 -4.06285500e-03  2.16358680e-02
#  -2.97433300e-03  8.53242900e-03 -2.78709200e-02  4.22930870e-02
#   3.58992280e-03 -4.45188800e-02  4.43651680e-02  8.88254200e-03
#   7.07661100e-02 -2.11570450e-02  2.72449350e-02 -2.88156200e-02
#   6.50301900e-02 -1.09586725e-02 -6.89623550e-03  1.35562360e-02
#   1.33504355e-02  6.84316040e-03  1.31311940e-02  6.88421900e-03
#  -2.22607800e-02 -3.88112300e-02 -5.48213420e-02  2.86909210e-02
#   4.35459650e-02  9.87030900e-03 -2.05039870e-02 -3.90856150e-02
#   7.75468700e-02  6.57064560e-03  1.82194520e-03 -1.27073960e-01
#  -2.66099160e-02  4.79257550e-02  4.17216300e-02  9.78679700e-03
#   1.15074920e-02 -5.75078280e-02 -1.04048856e-01 -3.04246880e-02
#  -6.56618700e-02  3.53351680e-03 -2.89495010e-02 -3.83836960e-02
#   1.69773460e-02  3.92604170e-02 -2.26165200e-02  2.56044950e-03
#   7.82358940e-02 -4.07853870e-02 -3.78135500e-03  9.29947900e-02
#  -3.86453570e-02 -4.92719560e-02  2.12157150e-02 -3.81240770e-02
#   2.54078970e-02 -1.29645085e-02 -3.93080640e-02  2.65353620e-02
#   1.24172320e-02  5.05628900e-03  3.50765550e-02  4.28732340e-02
#   3.77416160e-02  5.91002400e-02 -6.48011040e-02 -1.71929970e-02
#   2.44276000e-02  6.22502530e-03  4.53200380e-02 -7.49776100e-03
#  -3.00177100e-02  3.38264330e-02  2.67237180e-02  4.17544170e-02
#   2.85441410e-02  2.58245230e-02  9.04340500e-02 -3.13541370e-02
#   1.34887920e-02 -1.38009510e-03 -1.28223230e-02  2.31045500e-02
#   1.90184840e-02 -2.11876540e-02 -1.53876490e-02 -4.72972650e-02
#  -3.86763620e-02  5.87665900e-03  4.19092440e-02  6.72455950e-02
#   1.44923340e-02 -1.42253590e-02  4.45985100e-02  2.47087570e-02
#   1.94109450e-02  2.50829870e-02  1.58328450e-02  4.36094920e-02
#  -3.15848070e-02  6.34086100e-02 -5.09903540e-02  1.79725940e-02
#   5.05057570e-02 -2.26481720e-02 -2.35718950e-02 -2.26204820e-03
#  -7.92018250e-02 -8.43684400e-03  5.59002300e-02 -1.66713400e-02
#  -1.05914280e-02  5.51695970e-02  1.22300850e-03  1.52553110e-02
#   3.36873160e-02 -3.58128700e-03  2.13065840e-02  6.71302450e-02
#  -2.37841620e-02 -3.38372740e-02  9.49710800e-03  4.20177100e-03
#  -4.84568900e-03  2.48031150e-02 -7.83824700e-03  4.56051900e-02
#  -3.98697220e-02 -5.01720160e-02 -2.61767950e-02 -4.52464040e-02
#   1.16947290e-02 -3.27382000e-03 -3.66279800e-02 -2.98267850e-02
#  -1.04892645e-02 -3.31042670e-02  3.61777100e-02  6.58076850e-02
#   8.30443300e-03 -6.72203900e-02  3.88619640e-02 -2.15302390e-02
#  -2.76898970e-02  4.69837340e-02 -3.64432060e-03 -2.51382570e-03
#  -2.22916530e-02 -5.18481100e-02 -1.59575900e-02  6.28583360e-02
#   6.27516200e-02  2.21238430e-02  3.23186630e-02 -4.78351500e-02
#   1.90414580e-02  7.03839000e-02  3.06715470e-03 -1.53548940e-02
#   1.01393190e-02 -1.05287125e-02  7.59745500e-02 -1.81973820e-02
#  -5.09800760e-02  6.83632800e-02 -4.82774500e-02  3.39396340e-02
#  -2.29462240e-02  2.47606220e-03  3.55738550e-02 -2.56094560e-02
#  -1.69600210e-02  4.13020740e-02 -4.71243950e-04 -3.20420940e-02
#  -2.44667030e-02 -1.27011180e-02 -3.38114840e-02  3.07221860e-02
#   1.04139530e-02  8.08706360e-02 -3.73945940e-02  6.83864250e-03
#   1.18086920e-02 -2.37848350e-02 -2.95598170e-02  7.67734050e-02
#   3.46210230e-02 -7.48677230e-03  8.21219460e-02 -2.06313280e-02
#   3.02128960e-02  1.27493440e-02  1.16632310e-02  3.86908900e-02
#  -2.85593980e-02  1.39009710e-02  4.59252740e-02  5.85060000e-03
#  -7.05696500e-02 -4.99508680e-02 -1.97218270e-02  3.07514030e-02
#   1.17733590e-03  4.84247360e-02  2.23887480e-03 -4.89660800e-02
#  -1.34168770e-02  2.57496020e-03 -6.68993700e-02  4.32664230e-02
#  -6.06564320e-02 -2.00114590e-02 -2.05598420e-02  1.63196660e-03
#   6.04162500e-02 -6.87846360e-03  1.67837410e-03 -2.80048060e-02
#   2.15057200e-02 -9.42049500e-03  1.28829880e-03 -5.85750000e-02
#   3.06857880e-02  2.14488190e-02 -1.23521920e-02 -3.43420540e-02
#   2.41447650e-02 -1.46337050e-02  3.20567860e-02 -5.99477670e-03
#   4.46858960e-03  8.26250000e-02  1.66239230e-03 -4.48447060e-02
#   5.21744800e-02  4.28299100e-02  4.62470430e-02 -3.73164830e-02
#   6.69237600e-03  1.05775010e-02 -4.76964670e-02 -4.08224600e-02
#   2.84716000e-02 -7.92414800e-02 -2.08719060e-02 -1.09365600e-02
#   1.87738310e-03 -5.04819750e-02 -8.78242700e-02 -2.74173200e-03
#  -2.39536000e-03  3.31237840e-02  1.58562980e-02 -3.55922060e-02
#   1.51943680e-02 -1.06721630e-01  1.96754880e-02 -8.60064850e-02
#  -3.37341240e-03  4.09964840e-02 -8.55540600e-03 -6.32242000e-02
#   2.89490540e-02  2.98773570e-02  1.81377050e-02 -3.57569000e-02
#  -2.67978850e-02 -1.19345290e-02  7.47994700e-02  5.88202250e-02
#  -4.58900740e-02 -2.78227330e-03  1.11438810e-02  2.39506980e-02
#   1.39235050e-02  4.72236420e-02  8.10312500e-03  1.76185980e-02
#  -1.44026440e-02  5.51496900e-02  3.98571560e-03  7.21923500e-05
#  -1.33703610e-02  2.39115770e-02 -2.08346680e-02  1.22163380e-02
#  -6.50011000e-02  4.07433100e-02 -1.60195510e-02  1.69961860e-02
#  -1.00508740e-01  7.36115700e-03 -1.80504170e-02 -2.66030230e-02
#   2.16648080e-03  2.22891050e-02 -1.32338790e-02 -4.92188220e-02
#   1.23834180e-02 -1.13943920e-02 -5.48713600e-02  1.82273440e-02
#   7.20267700e-02  1.07875010e-02 -9.58229800e-05  6.02883360e-02
#  -1.38217640e-02  5.06551300e-02 -9.55491600e-03 -5.08548730e-02
#   5.61353340e-02 -4.68696400e-02  3.55314840e-02 -3.48253550e-02
#   1.86995710e-02  5.53574600e-02 -5.04441370e-02 -4.13232000e-02
#  -8.09113800e-03  8.86834630e-04  1.37094970e-02 -1.48037230e-02
#   2.98474730e-03  2.06158780e-02  5.97646500e-03 -3.01513470e-02
#   2.30256400e-02 -4.66430560e-02  3.94902680e-02 -5.57075250e-03
#  -3.20965830e-02 -4.94193360e-02  3.17691380e-02  2.63878600e-02
#   4.95495000e-05  2.18394060e-02  6.53732240e-03  3.20131070e-02
#   1.77485590e-02 -8.35995360e-04  5.85393570e-02  2.07238920e-02
#  -2.15059910e-02  4.96238880e-02 -4.39732260e-02  2.51760840e-02
#   8.12113660e-02  1.08104300e-03  4.88831620e-02 -4.05036730e-02
#  -5.86035240e-03 -4.54327460e-02  4.04530430e-02  3.69275320e-02
#  -5.33243900e-03 -6.65248200e-02 -4.32526880e-02  5.34217340e-03
#  -6.36552900e-02  8.53902000e-04  3.24119700e-02 -1.76301410e-02
#  -3.34985220e-02 -3.99448400e-03  1.42041500e-02 -7.86586800e-03
#  -1.52437380e-03 -4.73813940e-02 -4.00117900e-02 -2.82288100e-02
#   2.73456950e-02 -3.70278400e-02 -2.14242300e-02  1.73733550e-02
#  -3.70456760e-02 -1.29232200e-02  1.66275260e-02 -2.26802730e-02
#  -6.07099700e-02 -7.72124950e-03  3.73851020e-02  1.70680940e-02
#   4.61916350e-03  6.36522100e-03  5.20255980e-02  3.82484910e-03
#  -8.73223300e-03 -1.12065500e-02 -1.67916120e-02 -5.26369100e-02
#  -1.44777740e-02  3.13701900e-02 -2.55121180e-02 -1.83621830e-03
#   3.39855780e-02 -3.65114170e-02 -1.03248125e-02 -2.95829960e-02
#  -3.30970900e-02 -2.03909100e-02 -8.83294000e-03 -3.39843030e-02
#   1.74200700e-02 -8.12128800e-02  2.74884100e-02 -6.11316230e-02
#  -2.24536500e-02 -5.36163640e-02 -2.93685000e-02 -1.74521490e-02
#  -5.37519300e-03  8.57962400e-02 -5.64657900e-02  2.08799110e-02
#   3.28745900e-03 -3.62636220e-02 -5.11682960e-03 -8.90592260e-02
#   4.13355700e-02 -1.74372420e-02  1.25408310e-02 -1.04257060e-03
#   7.02092000e-05  5.91834400e-02 -1.39173220e-02 -7.78984100e-03
#  -1.11888420e-02 -3.76464350e-02 -4.53704070e-02 -2.36343300e-02
#  -5.75039200e-02  3.91612400e-02 -7.07765740e-02 -1.54023390e-02
#   1.29799220e-02  6.42817560e-03 -1.60015200e-02  1.34507020e-02
#  -2.12291240e-02  4.79358340e-03 -6.95062400e-03  3.82806200e-04
#  -4.38395550e-02  5.44655250e-02  5.57096070e-03 -1.82724580e-02
#  -1.60022170e-02 -2.50495200e-02 -6.20058970e-03 -1.62672700e-02
#  -2.87091120e-02  7.94292400e-02  4.46725640e-02  4.62292200e-02
#   5.85909760e-04 -4.64542060e-02 -6.81501100e-03  5.80634600e-03
#   8.36400540e-02 -8.45144100e-02 -9.66908000e-03  3.11316400e-02
#   1.90919790e-02 -3.37170920e-02  1.78659240e-02  4.63614870e-02
#   1.90196150e-02  6.85303200e-03  6.64851900e-02 -5.20660400e-02
#  -8.41995400e-03 -1.55112040e-02  1.76953770e-02 -3.16249300e-02
#   4.46520650e-03 -3.36781370e-02 -8.42561900e-02 -5.81879300e-03
#   2.84116790e-02 -3.25404920e-03 -4.19838580e-02  1.94031280e-02
#  -5.79798700e-02 -7.20823740e-03 -5.10639500e-02  5.74475560e-02
#  -4.59619570e-02 -7.87809700e-03  6.14489350e-02 -2.25869250e-02
#   3.80549200e-02  4.54399770e-02  2.67300620e-03 -2.00844310e-02
#   4.71295530e-02  7.42049800e-03  3.57177970e-02  4.00312170e-02
#  -4.82136980e-02  1.16289450e-02  2.51947530e-02 -6.21331370e-02
#   6.64737960e-03 -4.71125580e-02 -1.14631170e-02  3.90195300e-02
#   5.45584560e-02  2.97110550e-03  4.78673060e-02 -8.33672200e-03
#  -6.99534270e-03  1.82688410e-03  1.45010190e-02 -1.27530960e-02
#   1.26249120e-03  3.45943120e-02 -1.89911240e-02  3.00202160e-02
#   6.44891400e-02 -4.34190500e-03 -1.06250810e-02 -4.61325940e-02
#   5.84786240e-02 -5.53117740e-03 -3.01226490e-02  7.77302100e-03
#   4.74331200e-03 -1.26803810e-02  4.15421400e-02 -2.06282230e-02
#  -4.41645940e-02 -8.99448700e-03 -2.31860500e-02  2.09835620e-02
#   3.79256530e-02  7.43963060e-04 -5.73644500e-03  1.06762340e-02
#   1.62412710e-02 -8.66726800e-03  5.76331130e-02  5.76208900e-02
#   4.80082970e-02  1.65068940e-02 -7.44219600e-02  2.30727480e-02
#  -2.24131680e-02  5.16503640e-04  1.55019555e-02 -1.62950100e-02
#   3.47799170e-02 -3.54015640e-02 -1.51897200e-02 -1.83585830e-02
#   2.79451350e-03 -9.78084600e-04  2.91498470e-02 -2.17965110e-02
#   4.54806100e-02  2.54338030e-02 -2.50636020e-03  2.02230180e-02
#   1.12459150e-02  3.87893130e-02 -8.12430600e-03 -6.47517440e-02
#   1.35424030e-02 -8.46923400e-03 -5.66423700e-02 -4.60623300e-02
#   6.59310100e-02 -2.28470660e-03 -3.23117040e-02 -5.32789600e-02
#  -9.46310800e-03  6.51222000e-03  2.41989120e-02  1.58195910e-03
#   1.13296350e-02  1.88304540e-02 -3.22797970e-02  8.80792100e-03
#   8.97184200e-02  3.50613560e-02  5.56290970e-02  6.46752500e-02
#  -4.36349620e-02  1.45916800e-02 -6.38522500e-02 -2.62596720e-02
#  -1.73723380e-03  5.06289800e-02  5.82769940e-05  2.95782870e-02
#  -6.32654700e-02 -1.11025810e-02  3.19925730e-02  4.61375340e-03
#  -4.73196060e-03  2.24237260e-02  2.24522370e-02 -7.13590100e-02
#  -5.12244140e-02 -3.17132850e-02 -2.44327950e-02  7.15737200e-03
#   1.99011140e-02 -2.82440070e-02  3.32550900e-02  1.69493900e-02
#  -5.72340560e-02 -3.50630800e-02  3.24754100e-02 -4.80658240e-03
#  -4.32682970e-02 -8.20756900e-03 -4.28549570e-04 -1.33837230e-02
#   1.31371830e-02 -6.83423900e-03 -6.23566020e-02 -6.22076580e-02
#  -2.12154720e-02  8.29619400e-03 -5.81925140e-02  3.50828250e-02
#   4.93296500e-02 -1.38883720e-02  4.22848400e-02  1.31981590e-02
#   5.24873850e-03  1.81030370e-02 -5.02777470e-03 -2.11350560e-02
#   2.38215420e-02  6.72218530e-03 -1.57609100e-02  8.16377250e-03
#  -6.37593800e-03  3.31932200e-02  2.51543520e-02 -4.30649030e-02
#  -5.85859380e-02 -5.43829430e-02  2.52073540e-02 -2.90623810e-02
#  -6.53910200e-03  3.25958100e-02  2.50810250e-02 -1.21021300e-03
#  -3.30510500e-02 -4.87801800e-03  1.91814770e-02  4.57345000e-02
#  -1.50284980e-02 -4.22923900e-02 -1.85698570e-02 -1.06816830e-02
#   2.35808230e-02  1.62795040e-02  1.18008570e-02  4.56148870e-02
#   5.36186000e-02  6.81212540e-02  2.52611700e-02 -3.66292500e-02
#   1.30499240e-02  1.37743335e-02  2.05117390e-02 -4.05681600e-02
#   1.19559740e-02  3.62599500e-02 -2.23219820e-02  6.04524700e-02
#   3.23805400e-02  3.15711400e-02  3.78667300e-02 -4.99216130e-02
#  -5.54860760e-02  7.68435700e-02 -4.45234250e-02 -3.38016730e-03
#  -1.93530360e-02 -3.73645660e-03  8.39417800e-02 -4.05357960e-02
#  -1.57253610e-02  8.81123200e-03 -1.52499920e-02  8.30622900e-02
#   1.52262010e-03  2.85929800e-02 -9.08117600e-03 -8.80236500e-02
#  -1.55065020e-02 -2.86565850e-02  2.17278080e-02  7.20199900e-02
#   3.51369940e-02 -2.29738630e-02  1.50387780e-02 -1.87712830e-02
#   7.43983200e-03 -5.83814640e-02  7.82168300e-03 -1.77415420e-02
#  -1.00598410e-02  4.56905360e-02  6.93887000e-02 -1.41987195e-02
#   3.94940660e-03 -1.12282760e-02 -3.39775250e-03  8.55347300e-03
#  -6.20363280e-02  1.29153500e-03  4.52778860e-03 -3.08997580e-02
#   3.45623500e-02  2.47501900e-02 -2.22460100e-02  1.73624600e-03]

# %%
# Liste de textes à convertir en embeddings
texts = [
    "L'intelligence artificielle est fascinante.",
    "Les embeddings sont utiles pour la compréhension du langage.",
    "Google propose des outils puissants pour le machine learning."
]

# Génération des embeddings pour la liste
embeddings = await embedding_gemini.embed_batch(texts)

# Affichage des résultats
print("Embeddings des textes :")
for i, embedding in enumerate(embeddings):
    print(f"Texte {i + 1} : {texts[i]}")
    print(embedding)
    print("-" * 50)
# Out:
# Embeddings des textes :
# Texte 1 : L'intelligence artificielle est fascinante.
# [ 1.81776700e-02 -2.09075850e-02 -5.44802430e-02 -9.63946600e-03
#   6.27376400e-02  1.27255430e-02  3.43415630e-02 -7.27116460e-03
#   2.67239380e-02  3.95728460e-02 -1.18686950e-02  1.48777920e-02
#  -1.78073700e-02  2.46544260e-02 -1.59702770e-02 -2.36299970e-02
#  -2.32895110e-03  6.28842900e-02 -6.01169840e-03 -1.57406680e-02
#  -1.39493520e-03  2.37522310e-02  7.50586060e-03 -2.28362930e-03
#   3.76312730e-02 -2.94346960e-02  6.28428160e-02 -3.64647620e-02
#  -3.16046700e-02 -8.91882900e-03 -3.13005750e-02  1.40759820e-02
#  -3.40559450e-02 -8.68556700e-03  2.01852680e-02 -3.52584120e-02
#  -1.44373140e-02  3.58716250e-02  1.00795420e-02 -2.23056950e-02
#   2.05387210e-02 -5.94064030e-02  1.61044900e-03  1.27024920e-02
#  -1.22964010e-02  1.06089935e-02 -2.06480180e-02  3.95894700e-02
#  -1.54242230e-02 -3.62129030e-02  3.84125970e-02  1.72824140e-03
#   7.92602900e-02 -5.54205900e-03  1.04320515e-02 -2.95619370e-02
#   5.37521200e-02 -7.04318470e-03 -5.56583400e-03  2.04638470e-02
#   5.98051720e-03  6.39520400e-03  1.20062320e-02  2.18028690e-02
#  -6.05135220e-03 -3.32462400e-02 -4.87380030e-02  4.50114530e-02
#   2.47125940e-02  1.22007220e-02 -1.27059900e-02 -4.41035440e-02
#   7.56343500e-02  9.87368500e-03  1.04175600e-02 -1.09772200e-01
#  -3.05171260e-02  5.47124400e-02  4.54733220e-02  3.04508440e-03
#   1.39583300e-02 -5.41152060e-02 -1.02388170e-01 -3.53915100e-02
#  -6.38037850e-02 -3.74183480e-03 -3.24043330e-02 -2.88125070e-02
#   1.53734590e-02  4.88368700e-02 -2.34154000e-02  3.54710220e-03
#   5.96434700e-02 -3.06987190e-02  9.87034100e-03  7.91744300e-02
#  -4.87574450e-02 -3.84013020e-02  1.76825080e-02 -2.56939360e-02
#   3.47592270e-02 -6.14311730e-03 -5.41868730e-02  3.11619560e-02
#   9.48200750e-03  7.88830400e-03  2.67683000e-02  6.21587820e-02
#   3.19595520e-02  4.45968700e-02 -7.49111900e-02 -2.01986170e-02
#   2.47984360e-02 -5.96557700e-03  4.76413200e-02 -3.37727550e-02
#  -1.63610150e-02  3.93799880e-02  3.91910450e-02  2.90937630e-02
#   3.58578100e-02  2.40163440e-03  1.01892315e-01 -2.86908320e-02
#   2.60255500e-03  1.28158160e-04 -2.65820590e-02  3.46756500e-02
#   1.08323240e-02 -3.56216400e-02 -1.77480800e-02 -3.55299080e-02
#  -4.31479250e-02  1.89115260e-02  3.67002380e-02  4.49543860e-02
#   7.57252500e-03 -3.07588760e-02  5.34633850e-02  3.10245800e-02
#   3.31266800e-02  2.48685930e-02 -4.35281400e-04  4.52176260e-02
#  -3.55941580e-02  6.42413350e-02 -6.44940100e-02 -6.21877240e-03
#   5.82435200e-02 -2.31772870e-02 -4.28894500e-02 -1.94523540e-03
#  -8.17114800e-02 -2.08322960e-02  6.00903440e-02 -2.31210480e-02
#  -5.77934400e-04  4.00369060e-02  3.58535650e-02  2.06378300e-02
#   1.49643560e-02 -6.38176200e-04  1.27347370e-02  6.33315300e-02
#  -1.55827100e-02 -4.57610200e-02  4.69762460e-03  1.55617070e-02
#  -4.08381460e-03  1.38104465e-02 -3.71152900e-02  5.51637370e-02
#  -4.12941580e-02 -6.45864400e-02 -2.30734460e-02 -5.68961760e-02
#  -5.18963300e-03 -3.01493240e-02 -3.77209260e-02 -2.27502750e-02
#   4.64527750e-04 -4.22107000e-02  3.26852900e-02  6.34020700e-02
#   1.14201230e-02 -4.67371680e-02  3.86856600e-02 -2.72140070e-02
#  -2.71371830e-02  3.83564400e-02 -8.34580800e-03 -1.58370510e-02
#  -2.10898200e-02 -5.21163870e-02 -1.82631100e-02  4.61170970e-02
#   7.18900100e-02  8.36281700e-03  1.83158310e-02 -3.54102400e-02
#   1.76773130e-02  4.87047840e-02 -1.61840560e-02 -5.20799450e-03
#   4.85609470e-03 -8.75239400e-05  8.05018540e-02 -1.16025200e-02
#  -4.23016360e-02  6.02280420e-02 -6.67531000e-02  2.92456930e-02
#  -2.85560000e-02  1.23963370e-03  1.69990530e-02 -9.10776200e-03
#  -1.41686590e-02  2.68478100e-02 -2.11585610e-02 -2.85069530e-02
#  -2.94849980e-02 -1.57319880e-02 -4.64401650e-02  2.68848860e-02
#  -7.70931100e-03  9.59584800e-02 -2.84286440e-02  9.84426100e-04
#   6.33863800e-03 -3.94276530e-02 -3.90173530e-02  6.77835800e-02
#   3.44601500e-02 -1.26162540e-02  8.50646640e-02 -3.02401370e-02
#   3.77054740e-02  7.30458650e-03  6.99303950e-03  4.84393540e-02
#  -2.65837180e-02  1.88020560e-02  4.19217800e-02  1.45195080e-02
#  -6.91256750e-02 -3.93956450e-02  8.06426600e-03  2.14575340e-02
#   2.65602930e-03  4.26683430e-02 -3.27675800e-03 -3.34780550e-02
#  -1.22138950e-02  9.54849800e-03 -7.35767300e-02  3.48280200e-02
#  -6.08791750e-02 -4.79020550e-03  8.77548000e-04  1.89627460e-02
#   7.03539700e-02  2.11033430e-03  3.39354600e-03 -3.69566460e-02
#   2.19897700e-02 -3.21707300e-02 -3.75622460e-03 -5.90315350e-02
#   3.74977330e-02  1.89253280e-02 -1.04266390e-03 -4.60272300e-02
#   2.61098090e-02 -1.24980260e-02  1.67693700e-02 -8.49577500e-03
#   7.13009760e-03  7.41311900e-02 -1.01286730e-02 -4.87689260e-02
#   3.63538530e-02  3.78853600e-02  5.25584780e-02 -4.78886250e-02
#   4.16152900e-03  7.98460700e-03 -6.07760600e-02 -5.20696570e-02
#   6.99616460e-03 -7.56217840e-02 -1.41107880e-02 -2.58253930e-03
#   9.06033900e-03 -4.37659140e-02 -6.60151300e-02 -2.98370200e-05
#   1.25818020e-03  3.50479820e-02  2.36658790e-02 -3.25353480e-02
#  -5.81564150e-03 -1.02902300e-01  3.28256470e-03 -6.56167900e-02
#  -2.69193070e-02  3.74369140e-02 -1.27752280e-02 -5.34742920e-02
#   2.27028540e-02  2.46790440e-02  7.23391100e-03 -3.96133300e-03
#  -1.47696520e-02 -1.54699250e-02  5.15033570e-02  4.90873980e-02
#  -2.75838780e-02  3.49918800e-03  1.02368920e-02  3.03407760e-02
#   2.36110050e-02  3.00213700e-02  3.02517130e-02  1.39826100e-02
#  -2.49080860e-02  4.27824740e-02  1.37424850e-02 -1.05520360e-02
#  -3.22825800e-02  1.44261640e-02 -1.46448720e-02  5.99239860e-03
#  -6.23613500e-02  4.67397650e-02 -1.97605030e-02  2.74592660e-02
#  -9.94033700e-02  2.89254130e-02 -9.11016300e-03 -9.65349800e-03
#   1.05027310e-02  8.47846900e-03 -1.81017700e-02 -5.94402800e-02
#   1.73726900e-02 -2.07895200e-02 -7.52923400e-02  9.78311600e-03
#   7.35076700e-02  3.96903120e-02  1.11777480e-02  6.11701350e-02
#  -4.35150800e-03  3.74735740e-02  6.75198340e-03 -3.99041300e-02
#   4.86104530e-02 -5.78541640e-02  2.27326230e-02 -3.89660500e-02
#  -8.94575700e-03  6.89938960e-02 -4.06099820e-02 -2.32903700e-02
#  -2.00828670e-02  1.47604650e-02 -2.81354120e-04 -1.00533200e-02
#   5.47614700e-03  2.14585010e-02 -1.44337780e-04 -1.82609730e-02
#   2.29249200e-02 -4.37102100e-02  1.55206930e-02 -1.85643860e-03
#  -4.74143030e-02 -5.53255000e-02  3.96720360e-02  1.68211420e-02
#   1.31554340e-02  1.20204130e-02  1.38789250e-02  2.02192100e-02
#   2.53179820e-02  1.12383270e-02  5.27920000e-02  2.37813550e-02
#  -8.43537200e-03  4.92182300e-02 -3.23610000e-02  3.99118600e-02
#   9.71950200e-02  2.15707380e-02  4.47690930e-02 -1.96946880e-02
#   2.83102700e-03 -4.57420760e-02  3.83113100e-02  2.52180020e-02
#  -1.64330750e-02 -5.30747360e-02 -5.48683100e-02 -1.59509310e-02
#  -5.97705730e-02  9.08977900e-03  4.27985600e-02 -1.82975850e-02
#  -3.71217650e-02 -7.42725300e-03  2.63913680e-02 -1.43060630e-02
#  -1.56751100e-03 -6.84410000e-02 -3.54258160e-02 -2.38351670e-02
#   4.97002450e-02 -3.39845940e-02 -3.45502530e-02  3.44573200e-02
#  -4.57166770e-02 -9.95974700e-03  2.14445810e-04 -5.08585300e-03
#  -6.98873000e-02 -2.51268520e-02  4.87875680e-02  2.23383590e-02
#  -1.20950580e-02  1.60472170e-02  5.09884430e-02  1.22239050e-02
#  -1.60822530e-02 -1.62273480e-02 -5.69833070e-03 -5.33227320e-02
#  -2.73747280e-02  3.33550870e-02  9.19794430e-04 -5.86234360e-03
#   4.29824700e-02 -5.81271200e-02 -1.53827190e-02 -4.15225480e-02
#  -5.25834970e-02 -6.13309260e-03 -9.84730800e-03 -3.16290400e-02
#   2.68267280e-02 -9.80256300e-02  3.56975720e-02 -4.23661060e-02
#  -3.79875040e-02 -5.09540300e-02 -1.36079650e-02 -2.58945580e-02
#  -2.15852870e-03  7.52195340e-02 -5.36416300e-02  1.62993670e-02
#   2.25710440e-02 -4.70402050e-02 -8.43454600e-03 -1.01601860e-01
#   3.82067080e-02 -1.43065250e-02 -6.99641600e-03  1.12565495e-02
#  -1.20140930e-02  4.49438360e-02 -9.20132500e-04  1.44121630e-03
#  -2.40890460e-02 -2.21739730e-02 -1.31769900e-02 -2.43561140e-02
#  -7.30954700e-02  4.64932140e-02 -5.74634100e-02  8.85021700e-04
#   3.05209800e-04  1.66201220e-02 -3.52656300e-02  1.06337130e-02
#  -1.18796780e-02 -7.66393960e-04 -2.03696300e-02 -4.12303540e-03
#  -4.48341560e-02  4.97830300e-02  1.00466120e-02 -1.31666580e-02
#  -3.54560720e-03 -3.71524240e-02 -1.75210370e-02 -1.30889230e-02
#  -2.16224800e-02  7.40962100e-02  5.77072800e-02  2.96159830e-02
#   1.31773500e-02 -3.77474400e-02 -3.01201900e-03 -1.72464770e-02
#   9.00977900e-02 -8.94084050e-02 -1.97351630e-02  4.68415700e-02
#   2.00276490e-02 -2.76574320e-02  1.87281390e-02  5.44316880e-02
#  -4.39194540e-03 -2.60363000e-03  7.28518140e-02 -5.24951370e-02
#  -1.93475890e-04 -1.51034810e-02  2.82466150e-02 -2.19457670e-02
#  -2.62506470e-03 -1.78616700e-02 -6.36808050e-02  4.80749100e-05
#   2.37428770e-02 -1.87804270e-02 -3.26169170e-02  1.20310890e-02
#  -6.93487450e-02 -1.40682530e-03 -4.58140860e-02  6.62007900e-02
#  -6.74710650e-02 -1.84380020e-02  7.20170900e-02  7.12105260e-03
#   3.90617500e-02  1.18065440e-02 -8.26378500e-03 -2.40627530e-02
#   4.81463400e-02  2.65381580e-03  4.04233220e-02  2.59689100e-02
#  -3.48820280e-02  1.15206830e-02  2.65112560e-02 -6.78038300e-02
#   1.28586170e-02 -3.71474060e-02 -1.72322900e-02  4.55730370e-02
#   7.07631200e-02 -2.82845620e-03  4.00137800e-02 -6.61782750e-04
#  -1.29463240e-02 -5.35506660e-03  1.24063190e-02 -4.92705170e-03
#  -8.34267400e-03  1.97995210e-02 -7.78259340e-03  4.78959700e-02
#   6.70458150e-02 -1.24622965e-02 -5.00402100e-03 -5.99035920e-02
#   5.00113100e-02 -1.05209810e-02 -2.30860190e-02  1.23913140e-02
#   9.13411400e-03  1.02117470e-03  4.73499340e-02 -1.11250775e-02
#  -2.05587860e-02 -1.44951950e-02 -2.37605810e-02  1.15085940e-02
#   5.49108350e-02 -5.39043200e-03  1.66194700e-02  1.77902340e-02
#   3.16224180e-03 -1.23503420e-02  5.06147850e-02  6.08525000e-02
#   2.93835250e-02  1.61741130e-02 -6.51643800e-02  1.27862440e-02
#  -1.05068210e-02 -1.03521700e-02  2.01391900e-02 -2.33284400e-02
#   3.60558740e-02 -2.70646620e-02 -3.41827400e-02 -2.24945600e-02
#   4.35008000e-03  1.13981320e-03  4.38703630e-02 -2.82578260e-02
#   1.94003490e-02  2.89722960e-02 -1.50851380e-02  1.52829520e-02
#   1.89325900e-02  4.41987630e-02 -1.25733990e-02 -6.99643600e-02
#   1.87237840e-02 -1.55261550e-02 -4.85978650e-02 -3.52846420e-02
#   8.07003300e-02 -4.86337350e-03 -2.07973180e-02 -5.90279140e-02
#  -8.79310700e-03 -1.13433790e-02  3.39481270e-02 -1.32195980e-03
#   5.87163100e-03 -4.31888740e-03 -3.30203920e-02  1.39805660e-03
#   8.41441200e-02  4.21892330e-02  4.55708760e-02  7.88069200e-02
#  -3.12641820e-02  1.04235520e-02 -6.25682700e-02 -1.81831870e-02
#  -8.12380200e-03  2.91725840e-02  2.16798300e-02  1.54841140e-02
#  -5.46505860e-02 -2.81841540e-03  2.63981000e-02 -4.15046700e-03
#  -8.86470600e-03  2.57622060e-02  2.46788400e-02 -5.95532950e-02
#  -7.92318300e-02 -2.66704260e-02 -3.88198700e-02  1.98379480e-02
#   1.80986700e-02 -3.41805330e-02  5.68756040e-03  2.91551110e-02
#  -6.13732800e-02 -3.33550050e-02  3.95814630e-02 -8.25398300e-03
#  -5.53053900e-02 -1.11119860e-02 -8.86562700e-03  1.15180130e-03
#   6.69109960e-03 -3.17480040e-03 -4.04431200e-02 -6.81086100e-02
#  -2.07220070e-02  9.24777200e-03 -5.04938800e-02  4.13945350e-02
#   3.10726180e-02 -1.07521545e-02  3.46165600e-02  8.83289150e-03
#   2.25047580e-03  1.99151400e-02 -1.00683560e-02 -8.73020100e-03
#   1.72315390e-02  2.57190820e-02 -1.17069270e-02  2.04333460e-02
#  -1.25896830e-02  3.42514250e-02  3.85708140e-02 -4.24625200e-02
#  -3.60649000e-02 -5.32361870e-02  9.05229900e-03 -3.56333180e-02
#  -2.10408800e-02  4.95375500e-02  1.86022760e-02  1.72253660e-02
#  -2.79143450e-02 -1.66230910e-02  1.45904180e-03  5.41010570e-02
#  -3.52056660e-02 -6.52340650e-02 -2.26139540e-02 -7.55217250e-03
#   2.86973290e-02  1.03269860e-02  1.76898980e-03  1.72446740e-02
#   6.32632300e-02  6.70673500e-02  3.29610030e-02 -4.57132400e-02
#   1.53902400e-02  2.79771960e-03  1.68376790e-02 -4.95014670e-02
#   1.46491295e-02  2.90786070e-02 -2.30880040e-02  7.48115260e-02
#   2.14964490e-02  4.16884830e-02  2.95766600e-02 -4.44267500e-02
#  -6.63039600e-02  5.90731500e-02 -4.76286370e-02 -1.55886180e-03
#  -1.42546180e-02 -1.34640730e-02  7.41057200e-02 -3.14469820e-02
#  -1.43757000e-02  2.13685460e-02 -2.23920460e-02  8.36045440e-02
#  -4.98944240e-03  4.11252830e-02 -3.60563750e-03 -8.74863640e-02
#  -2.57310230e-02 -1.11712900e-02  1.84541070e-02  6.67673600e-02
#   4.02609450e-02 -3.20417620e-02  1.56657600e-02 -3.76518850e-02
#   6.65219360e-03 -4.26540860e-02  1.81312750e-02 -3.06623500e-04
#  -1.29097870e-02  5.63714170e-02  3.54703480e-02 -1.61976700e-02
#  -7.93203900e-03 -7.96137600e-03  8.77536800e-03 -2.10215760e-03
#  -5.78760100e-02  1.29918600e-02 -1.41111070e-03 -3.11614400e-02
#   6.08463540e-03  3.50608750e-02 -6.02251300e-03  3.03062500e-02]
# --------------------------------------------------
# Texte 2 : Les embeddings sont utiles pour la compréhension du langage.
# [ 1.59014480e-02 -2.08143350e-02 -3.67774100e-02  9.28703200e-03
#   3.35290800e-02  3.37552500e-02  2.27616950e-02 -2.05797870e-03
#   2.43672400e-03  4.93991640e-02 -3.26476400e-02  9.33946800e-03
#  -2.87353490e-02 -2.30815420e-04 -2.43171340e-02 -2.50373180e-02
#   2.97311710e-02  1.10369370e-02  3.34379860e-02 -8.65719700e-03
#  -2.42190730e-02  1.01508120e-02  1.97446180e-03 -9.48836900e-03
#   1.97440270e-02 -3.49587760e-02  5.59018130e-03 -1.25135620e-02
#  -1.64909050e-02 -2.19162010e-02 -2.94591190e-02  3.85453000e-02
#  -1.64054730e-02 -5.43992550e-03  9.06300200e-03 -1.56026360e-02
#  -1.41826365e-02 -1.14079490e-02 -5.63985760e-03  2.48867500e-03
#   2.38048040e-02 -5.30702770e-02  4.37896300e-03 -8.84348700e-03
#  -3.05139440e-02 -1.22675560e-02 -1.74496490e-02  3.54575960e-02
#  -2.61493960e-02 -4.96914200e-02  4.73557670e-02  1.20587060e-03
#   8.30328100e-02 -2.75219700e-02  6.44547770e-03 -2.67286410e-02
#   4.93754500e-02 -2.23818350e-02 -7.98879300e-03  1.06404520e-02
#   3.63199200e-04 -1.59822810e-02  4.53551530e-04  2.64249460e-02
#  -3.68514250e-02 -5.03603260e-02 -3.81686300e-02 -4.27806900e-03
#   2.65428420e-02 -3.32719160e-03 -1.05095245e-02 -4.75696400e-02
#   3.99561230e-02  5.67044040e-03  3.26816340e-04 -1.16894850e-01
#  -2.44396860e-03  5.07786900e-02  1.19413680e-02  3.91016230e-02
#   3.46750540e-02 -3.75044460e-02 -7.74285900e-02 -1.30048110e-02
#  -7.23952950e-02  4.31778320e-02 -6.15218600e-02 -1.17628100e-02
#  -1.73752960e-02  4.06732220e-02  2.92401300e-04  5.29668100e-03
#   2.67119950e-02 -4.31962400e-02  2.42441030e-03  5.70744200e-02
#  -2.09000370e-02  5.99570150e-03  1.13796150e-02 -5.95180200e-03
#   1.64969600e-02  2.74572020e-02 -6.39554860e-02  2.48487870e-02
#   3.73922660e-02 -5.13823800e-04  1.64212500e-02  8.27489940e-02
#   6.73767830e-03  6.84252900e-02 -6.09503650e-02 -2.83515800e-02
#   1.53990590e-02  3.75562700e-02  3.37768350e-02 -5.59527800e-02
#   7.58202750e-03  3.66353770e-02  5.24345820e-02 -1.18890945e-02
#   1.78607780e-02 -5.32565500e-03  8.82952200e-02 -3.20154840e-02
#   3.09261980e-02  1.73925500e-02 -1.48799150e-02  2.13202570e-02
#   3.05714000e-02 -1.17541040e-02 -2.48362900e-03 -2.95708380e-02
#  -3.79711600e-02  4.94446230e-02  7.76442660e-02  6.24004270e-02
#   2.64465080e-02  1.46764960e-02  5.45279100e-02  6.64465800e-02
#   3.21942420e-02  3.19981240e-02  1.00368880e-03  8.42777000e-02
#  -4.61167950e-02  5.33251430e-02 -5.13172930e-02  4.41664100e-03
#   3.08327600e-02 -4.85038980e-02 -5.67828380e-02  1.43940920e-03
#  -9.31964700e-02  1.08962670e-02  5.03876000e-02 -2.94814460e-02
#  -2.11385230e-02  3.78272100e-02  7.99957800e-04  1.91577190e-02
#   3.65710740e-02 -1.15988560e-02 -1.18509885e-02  3.74643600e-02
#   2.04165480e-02  7.53815900e-03 -1.09672425e-02  6.07251380e-03
#  -1.29133845e-02 -1.01866230e-02 -3.76349050e-02  2.69911740e-02
#  -4.97441500e-02 -5.14156560e-02 -3.55234740e-02 -1.80020220e-02
#   1.73852600e-03 -5.70937600e-03 -1.40856495e-02 -7.98269550e-03
#  -9.76874000e-03 -5.46672640e-02  2.80453640e-02  5.32000920e-02
#   5.38006650e-02 -5.78908180e-02  4.82764880e-02 -3.50246880e-02
#  -3.89256400e-02  2.02706570e-03 -2.59098840e-02  1.84675850e-03
#  -4.25366700e-02 -6.31563300e-02 -5.69133570e-02  1.84480730e-02
#   3.08551300e-02  1.09146870e-02  3.78520300e-02 -3.07070840e-02
#   1.19094215e-02  7.15574550e-02  3.33223160e-02 -1.07286330e-02
#   3.91859500e-02  1.94921660e-02  5.43480440e-02 -1.61225350e-02
#  -6.41122300e-02  1.67071190e-02 -1.67693050e-02  3.50560100e-02
#  -1.96591930e-02 -1.57924850e-02  3.62253980e-03 -1.05850750e-02
#   1.43343940e-03 -9.81452800e-03  2.78853000e-02 -3.22473120e-02
#  -6.07451330e-03 -3.86422720e-02 -3.04274340e-02 -5.32387760e-03
#   3.03094350e-02  5.09827030e-02 -1.55271260e-02  1.53172140e-02
#  -8.91465900e-03 -2.13717540e-02  9.78060500e-03  8.37015960e-02
#   3.82821900e-02 -2.27951260e-02  6.64305240e-02 -4.31771730e-02
#   3.10355020e-02 -9.82547500e-04  2.75891680e-02 -2.20844000e-03
#  -2.87782810e-02 -6.76949040e-03  1.86075140e-02  2.52694920e-02
#  -2.12543050e-02 -2.99624880e-02 -1.50017460e-02  5.50598760e-02
#  -3.78524950e-03  5.43066400e-02  1.16239680e-02 -3.60006200e-02
#  -2.18507300e-02 -1.91482850e-02 -1.01218850e-01  5.02536150e-02
#  -2.73285790e-02  5.33712330e-03 -3.10819620e-03  3.07973250e-02
#   4.32790440e-02  2.34112010e-02  1.69630440e-02 -3.36771720e-02
#  -3.59437080e-03 -3.43934600e-02  5.21602850e-02 -4.57732380e-02
#   1.59963650e-02  5.42790800e-03  3.96189000e-03 -1.50065120e-02
#  -9.33727100e-03  1.83351240e-03  1.32801740e-02  4.65331080e-02
#  -7.47869350e-03  5.00035840e-02 -5.62334570e-03 -4.80062200e-02
#   5.78151460e-02  3.07484770e-02  8.90915000e-03 -4.48454300e-02
#   8.12321600e-03 -4.13705700e-03 -3.16846220e-02 -4.17279970e-02
#   1.32861280e-02 -6.39434000e-02 -1.70091320e-02 -4.03203330e-02
#   1.89457980e-02 -4.93135940e-02 -2.61517600e-02  1.51189575e-02
#   2.01823600e-02 -3.16675080e-03  2.87154750e-02 -2.13522870e-02
#   2.71476920e-03 -1.01622716e-01  1.18034080e-02 -6.36987000e-02
#   8.61931800e-03  4.17067330e-02 -1.96114390e-02 -5.72928900e-02
#   2.65543260e-02  2.13012020e-02  7.65240700e-03 -6.38108900e-03
#  -9.88292900e-03 -3.08464710e-02  5.54656160e-02  3.44884020e-02
#  -1.48594700e-02  1.27203550e-02 -3.97904700e-03  5.74999680e-02
#   4.86802500e-03  6.85031300e-02  3.85854100e-04  9.90067050e-03
#  -5.32726460e-02  1.58051940e-02  1.48525160e-02 -2.62769670e-02
#  -3.47822980e-02  1.27893590e-02  2.75885560e-02 -2.41409170e-02
#  -3.76888100e-02  4.17421500e-02 -2.86891200e-02  2.92680970e-02
#  -8.39563500e-02 -2.96915160e-03 -8.68940700e-03 -2.58456700e-02
#   1.47841390e-02  5.00739600e-02 -2.50660600e-02 -3.58925570e-02
#   2.62973640e-02 -3.20664100e-02 -4.39482100e-02 -6.57355600e-04
#   9.88033400e-02  1.11866410e-02  3.76322680e-02  7.63376700e-02
#   2.52495110e-02  3.90195100e-02 -4.82294760e-03 -2.83497330e-02
#   9.21881200e-02 -3.94830780e-02  2.62765440e-02 -9.80329050e-03
#  -1.30726010e-02  4.27238870e-02 -2.21564200e-02 -3.53934430e-02
#   1.13164760e-02 -7.52654400e-03 -3.22136300e-02  1.66076600e-02
#   9.50264500e-03  3.29058880e-02  2.77270940e-02 -4.49115630e-02
#   5.64669520e-02 -4.64410520e-02  1.45134460e-02 -9.39266000e-03
#  -3.30160370e-02 -3.84000880e-02  2.10268240e-02 -1.28058840e-02
#  -2.64355470e-02  3.36674680e-02  4.97080120e-02  1.72793530e-02
#   2.01714910e-02 -5.02524300e-03  6.39176000e-02  1.92444140e-02
#  -2.54816280e-02  3.59596160e-02 -3.77111660e-02  4.13614620e-02
#   1.38187960e-01 -5.17430830e-02  4.04250660e-02 -1.73233080e-02
#  -1.36244030e-02 -4.05623020e-02  4.10660600e-02  5.62275150e-03
#  -7.97272900e-03 -4.02174300e-02 -7.13561700e-02  1.80978030e-02
#  -3.72737530e-02  2.58431250e-02  6.87130630e-03 -3.28004620e-02
#  -4.05403150e-02  1.74490700e-02  4.73586050e-03  1.08361095e-02
#   1.04098140e-02 -4.03968000e-02 -5.62872850e-02 -4.56880270e-03
#   3.41880400e-02 -3.99622540e-02 -2.32384630e-03  1.96801930e-02
#  -4.50939800e-02 -3.81474050e-02  1.69458330e-02 -5.44843860e-02
#  -6.53080500e-02 -6.02123100e-02  2.16116460e-02 -1.38605640e-02
#   1.48361680e-02  5.01687550e-03  5.87958840e-02  1.87060680e-02
#  -3.87299500e-02 -1.11046340e-02 -1.44892140e-02 -4.02540380e-02
#   5.54180400e-03  2.54404730e-02 -5.67861650e-03 -2.09131520e-02
#   3.94912300e-02 -2.81502290e-02 -2.31565300e-02  3.95093770e-03
#  -1.57968200e-02  1.82386730e-02 -2.46894940e-03 -2.14134080e-02
#  -1.01949010e-03 -7.93127340e-02  3.78286470e-02 -3.00805050e-02
#  -3.60613500e-02 -2.48864440e-02  1.56851370e-02 -2.83477270e-02
#  -1.30314460e-02  5.53729000e-02 -2.96931340e-02  1.43177330e-02
#   1.50206940e-03 -7.57914800e-02 -1.82036570e-02 -1.13664180e-01
#   1.23661980e-02 -6.10083760e-03  1.99684520e-03 -1.27187670e-02
#  -2.02104260e-02  8.49153200e-02  9.94329000e-03 -1.29263710e-02
#  -2.00995700e-02 -5.38409400e-02 -2.02989800e-02 -2.41903140e-02
#  -5.79202700e-02  3.90688740e-02 -5.61475700e-02 -2.95391180e-02
#   1.92311200e-02  9.97453650e-03  1.10168556e-04 -2.65086070e-02
#  -4.22729550e-02 -2.27162060e-02 -2.81455240e-02  1.56615530e-02
#  -5.13362660e-02  6.92986900e-02 -2.92311070e-02 -2.11441270e-02
#   1.28220490e-02 -3.37801460e-02 -3.91443220e-02  8.65140300e-03
#  -3.44449120e-03  4.44493850e-02  7.29769600e-02  3.89174400e-02
#  -1.45076710e-02 -3.77519800e-02  1.00845690e-02 -2.31210960e-02
#   9.23069700e-02 -1.09398365e-01  2.01504630e-03  3.85087300e-02
#   2.21040080e-02 -4.99734100e-02  3.66006860e-03  3.11176220e-02
#   2.74575040e-02  1.29968730e-02  6.31845150e-02 -4.37882600e-02
#  -7.24870200e-03 -1.21954260e-02 -1.32018850e-03 -1.06775230e-02
#   4.94319400e-02 -3.66109900e-02 -8.91858000e-02 -2.84987070e-02
#   2.29427550e-02 -1.14391500e-02 -4.44775750e-02 -4.77058350e-03
#  -5.58813750e-03  2.46368130e-02 -3.77259700e-02  2.44250330e-02
#  -8.80420660e-02 -1.57963820e-02  2.98835470e-02  7.09983470e-03
#   6.95666950e-03  1.15225110e-02  8.19785100e-03 -4.10591620e-03
#   3.62251480e-02 -1.98945200e-02  5.33715600e-02  3.76986530e-02
#  -4.46102360e-02 -3.46705300e-04  4.22661100e-02 -7.76839600e-02
#   3.23357470e-02 -1.88307040e-02 -2.54624400e-02  6.60608400e-03
#   4.48101400e-02 -1.33944550e-02  2.85136290e-02 -8.78201200e-03
#  -8.80275400e-03  4.50674260e-02  2.27759310e-02 -5.41307100e-03
#  -2.61465520e-02  3.83089900e-02  2.52274070e-02  4.05972530e-02
#   3.24844160e-02  1.51561650e-04 -4.43832650e-02 -4.28051900e-02
#   7.34796200e-02 -3.20179600e-02 -2.76185260e-02  6.79774950e-03
#   2.99096000e-02  3.67348380e-02  2.81481400e-02  2.46482200e-03
#  -4.01485260e-02 -3.89518780e-02 -1.11207890e-02 -2.40859220e-02
#   3.71801700e-02 -3.18527930e-02 -1.17332390e-02  6.73356600e-02
#   2.41666030e-02  6.14004000e-04  6.34393200e-02  7.11504400e-02
#   6.66205960e-03  2.17418630e-03 -4.62531900e-02  3.42651530e-02
#  -3.71766760e-02 -3.46136900e-02  8.75430400e-03 -4.28499800e-03
#   2.44485920e-02 -3.26681800e-02 -5.32976800e-02  2.01006960e-03
#   5.64991160e-02 -1.47294160e-02  5.57327750e-02 -3.96040800e-02
#   2.88284800e-02  5.31349480e-02  2.09207090e-03 -1.64117520e-02
#   3.53078620e-04  4.50516160e-02 -2.81104860e-02 -3.02096050e-02
#   1.45656570e-02 -1.21426360e-02 -5.51239770e-02 -5.43472400e-02
#   7.70941700e-02 -8.90660700e-03 -4.64901850e-02 -5.21129440e-02
#  -2.68098250e-02  1.87098800e-02  1.75652400e-02 -1.44181870e-02
#  -2.40087600e-03 -1.66453120e-02 -2.94960140e-02 -6.61927550e-03
#   6.33000060e-02  4.05555100e-02  4.80785030e-02  6.01814300e-02
#  -1.62231750e-02  3.38939060e-02 -4.44023120e-02  2.85668500e-02
#  -3.91901960e-02  1.10977655e-02  2.92714050e-02 -6.14050400e-03
#  -6.92213400e-02 -3.59281340e-04 -2.16145720e-02 -3.48992650e-02
#  -2.44128540e-02  2.90967900e-02  2.95828280e-02 -5.69573750e-02
#  -5.44504100e-02 -2.60072500e-02 -2.10997160e-02 -1.27047030e-02
#   2.76362970e-02 -1.86565350e-02  6.16401500e-03  1.05443350e-02
#  -3.44833250e-02 -5.15131000e-02  3.06447630e-02  6.16614900e-03
#  -2.27104540e-02 -3.31462400e-02 -2.72777550e-02  1.91803220e-02
#  -2.23915350e-02 -4.78212160e-02 -4.46310450e-02 -5.53920680e-02
#  -4.29443940e-02  8.10349000e-03 -6.44668340e-02  1.65963900e-02
#   5.51818420e-02 -3.75388200e-02  3.62436000e-02 -1.01106170e-02
#  -2.26698220e-02  5.42827550e-02 -7.68297170e-03 -9.17523050e-04
#   7.76706780e-03  1.47001360e-02 -3.62505500e-02 -3.87776460e-03
#  -4.96241970e-02  4.74321250e-02  3.33323500e-02 -2.23501180e-02
#  -4.79325430e-02 -6.67177700e-02  1.71024800e-02 -1.56145990e-02
#  -1.88862360e-02  4.20605350e-02  4.13178020e-02  1.71900910e-02
#  -1.92337110e-02 -1.40296410e-02  8.04298300e-03  1.91473420e-02
#   5.27063100e-03 -6.33287600e-02 -4.53385820e-02  5.79465550e-03
#  -1.53727840e-02 -3.02502850e-02 -9.35330460e-04  2.60589290e-02
#   5.56838600e-02  4.13254420e-02  3.94619500e-02 -2.78492980e-02
#  -1.56697760e-02  4.01273100e-02  3.17134670e-02 -5.03666900e-02
#   5.71671300e-03  1.02324840e-03 -4.92818020e-02  6.57246600e-02
#   4.51845380e-02  4.15295900e-02 -7.08701600e-03 -7.01032400e-02
#  -4.66161780e-02  5.40587530e-02 -3.50907370e-02 -1.95865610e-02
#  -2.70649730e-02 -2.38961300e-02  5.07079770e-02 -4.17972500e-02
#   4.41592370e-03  1.21160760e-02 -3.10599300e-03  9.83612100e-02
#   2.24107690e-02  3.38310860e-02 -1.84803800e-02 -6.23824970e-02
#  -4.58923700e-02 -1.69864650e-02  2.20907460e-02  7.98770200e-02
#  -6.63122340e-04 -5.23140320e-02 -1.52031400e-02 -4.59021140e-02
#   2.84569340e-02 -4.44254350e-02 -1.64065900e-02  8.10409000e-03
#  -7.72034560e-03  2.61606970e-02  6.48551800e-02 -4.14702970e-02
#   4.33362200e-03  9.69573200e-03 -7.65774630e-03  3.40404800e-02
#  -4.49329280e-02 -2.80024880e-03 -2.33803950e-02  2.92888250e-02
#   4.56512270e-02  3.20102420e-02 -7.81140660e-03  2.78970800e-02]
# --------------------------------------------------
# Texte 3 : Google propose des outils puissants pour le machine learning.
# [ 1.22546480e-02 -4.06768430e-02 -5.46855630e-02 -1.13422770e-02
#   6.67134450e-02 -3.65284900e-03 -4.45641000e-03 -1.48453610e-02
#  -2.20754480e-02  3.27251370e-02 -1.11098240e-02  3.41621750e-02
#  -2.58487030e-02  2.50915000e-02  1.81261230e-02 -4.67320300e-02
#  -1.11324770e-02  1.38269510e-02  1.58196610e-02  4.05814500e-03
#   2.79222970e-02  3.45270320e-04 -2.20081920e-02 -6.07086570e-02
#  -7.47964160e-03 -3.09390480e-02  2.37763840e-02 -1.90223400e-02
#  -4.20625730e-02  1.55477690e-02 -3.51667960e-02  1.37460360e-02
#  -3.13861400e-02  2.88341300e-02  1.47139360e-02 -2.31775200e-02
#  -8.86176600e-03  9.26041300e-03 -2.84761420e-04 -2.25581300e-02
#   2.45720170e-02 -5.57642430e-02  9.25531200e-03  4.66157830e-02
#  -2.31640700e-02  3.79699450e-03  2.53958590e-02  2.54611450e-02
#   1.06040930e-02 -5.48662730e-02  3.09593470e-02  2.29709610e-02
#   9.02635160e-02 -1.16343260e-02 -1.44234120e-02 -3.02681080e-02
#   1.49440225e-02 -2.44830530e-02  4.19575240e-02  7.59288500e-03
#   3.96590350e-03  1.33192650e-02  6.68825770e-03  3.41420400e-02
#  -3.91325840e-02 -4.37164980e-02 -2.01264170e-02 -2.42518170e-02
#   3.05846100e-02  2.61957810e-02 -1.03632985e-02 -3.38464300e-02
#   5.22941100e-02 -5.95245500e-02 -2.91103260e-02 -1.25388800e-01
#   4.33203400e-03  3.63750420e-02  3.46684500e-02  3.55684100e-02
#  -2.99726730e-03 -5.74624400e-02 -7.49897100e-02 -3.50907220e-02
#  -6.02926000e-02  1.90181860e-02 -6.94914600e-02 -3.49005700e-02
#   1.49935520e-02  1.51177980e-02 -5.66659770e-03 -4.12528370e-02
#   9.40261600e-02 -2.47154550e-02 -1.59831530e-02  8.27036500e-02
#  -7.12364200e-03 -5.13442340e-02  1.10220825e-02 -6.20146170e-02
#   5.46197400e-03  3.29616300e-03 -2.01781560e-02  9.99719600e-03
#   1.32121530e-03 -6.16192170e-03 -1.89946140e-02  5.37133440e-02
#  -1.68031420e-02  5.70509470e-02 -6.95563500e-02 -1.97755750e-03
#   1.33466600e-02  2.36313370e-03  4.18546570e-02 -4.13215160e-02
#   7.88238100e-03  5.61106700e-02  3.04843020e-02  3.88482850e-02
#   1.44783750e-02 -1.08159400e-02  7.05392600e-02 -6.98469770e-03
#  -2.01955160e-02  2.50859130e-02 -4.23389200e-02  2.97197330e-02
#   5.96716180e-02 -1.55948100e-02 -7.60129100e-03 -4.68326170e-02
#  -3.41340680e-02  5.08299320e-02  7.13659300e-02  7.47369300e-02
#   2.69611180e-02 -2.59833480e-02  8.60868600e-03  3.56650350e-02
#   8.82994270e-04  2.20887460e-02 -1.90315000e-02  3.19976880e-02
#  -2.29176260e-02  6.56222550e-02 -8.17568500e-02  2.78509370e-02
#   2.99380100e-02 -1.82045250e-02 -3.63395140e-02  5.59642450e-03
#  -6.35157300e-02 -1.66383740e-02  7.95193400e-02 -2.11419470e-03
#  -7.68536930e-03  8.81267200e-02  4.48422360e-02  1.02160810e-02
#   4.42962000e-02  2.98491550e-02  1.88816820e-02  5.61629350e-02
#  -3.51353180e-02 -2.42522120e-02 -7.73552200e-03  4.44984100e-02
#   2.34380010e-02  1.40150020e-02 -2.82919570e-02  4.45833950e-02
#  -4.07626030e-02 -4.70160200e-02 -1.04544600e-02 -3.52734600e-02
#   1.05012450e-02  2.02206280e-02 -2.34629200e-02 -1.36980280e-02
#   2.20713320e-02 -3.47906350e-02  3.77161760e-02  6.90578740e-02
#   3.07628000e-02 -4.06186880e-02  4.43170370e-02 -1.67667530e-02
#  -4.60462870e-02  9.10081800e-03 -8.25417300e-03 -3.34613700e-02
#  -2.88689270e-02 -6.17599060e-04 -1.15595690e-02  5.53470030e-02
#   3.18180730e-02  3.69642950e-03  5.60510300e-02 -2.59123260e-02
#   3.11321320e-02  5.21683730e-02  1.93837500e-02 -9.56840350e-03
#   1.85034550e-02  6.04299300e-03  8.70708500e-02 -1.92746180e-02
#  -7.82366600e-02  5.38108460e-02 -3.68065720e-02  1.44243410e-02
#   8.13766150e-04  2.99013220e-02  5.72009120e-02 -2.05709230e-02
#  -4.13141540e-03  3.19834580e-02  2.38606800e-02 -4.13399230e-02
#  -6.44944300e-02 -1.27651090e-02 -4.21172400e-02 -9.94610800e-03
#   7.38487440e-03  7.14408400e-02 -3.55069700e-02  2.00934150e-02
#   1.70352720e-03 -1.18971150e-02  1.34504010e-02  8.35965700e-02
#   2.30616980e-02 -3.55065900e-02  6.89086300e-02  1.63875930e-02
#   4.86203540e-02  2.98071900e-03  4.51799850e-02  3.03575700e-02
#  -5.84948000e-02  1.12808980e-03  3.51460800e-02  1.12869200e-02
#  -7.67167300e-02 -6.71153800e-02 -3.48692160e-02  7.12402300e-02
#  -6.13327560e-03  7.05517000e-02 -2.51115190e-02 -3.36897370e-02
#  -5.01877850e-02 -1.43446475e-02 -6.74039350e-02  3.68736420e-02
#  -6.37455360e-02 -6.71178000e-03 -1.52087850e-02  2.49717070e-02
#   3.01646700e-02 -1.31858210e-02  1.36131560e-02 -2.60904300e-02
#  -1.44927960e-02 -3.15821100e-02  4.10716830e-02 -6.38042100e-02
#   2.82333140e-02  2.26529670e-02 -2.81390960e-02 -5.01648630e-02
#   3.56366700e-02  2.13821360e-02  2.55412760e-02  1.65869820e-02
#  -7.61288870e-03  6.21235330e-02  8.93020130e-04 -5.10094100e-02
#   2.76522670e-02  5.55353050e-02  1.45866640e-02 -5.42535900e-02
#   2.70934720e-02  6.60039700e-03 -2.74886540e-02 -5.58176230e-02
#   1.02006920e-02 -7.76248100e-02 -4.92023380e-02 -2.03171040e-02
#   1.08919665e-02 -5.58768500e-02 -5.84088080e-02  2.79968920e-02
#   1.35808390e-02  3.10927740e-02  1.24457130e-02 -3.03377550e-02
#  -2.10589170e-03 -8.66067860e-02  3.03552110e-02 -8.74116200e-02
#   2.50738040e-02  2.67225040e-02 -9.30404900e-04 -5.42618070e-02
#   4.52088200e-02  3.67034150e-02  1.26788110e-02  1.51554470e-05
#  -2.99084400e-02 -1.32409660e-02  4.99796640e-02  4.20815300e-02
#  -9.91966500e-03  4.55479900e-03 -4.49807060e-03  5.72896940e-02
#   4.13360260e-03  5.34704140e-02 -3.97710270e-03 -2.26244350e-03
#  -1.54723230e-02  4.82692680e-02 -8.77884700e-03 -4.79455400e-02
#  -7.54147000e-02  9.28706500e-04 -1.70073300e-02  2.12767600e-02
#  -7.67130400e-02  1.25107440e-02 -1.03771770e-02 -7.88138600e-03
#  -6.36850740e-02 -2.30631920e-02 -1.66612840e-02 -3.67061640e-02
#  -9.64814100e-03  1.65117120e-02 -1.17556360e-02 -2.60608940e-02
#   3.03549200e-02 -4.99543200e-02 -4.09430200e-02  7.64511700e-03
#   1.00036494e-01 -7.06440600e-03 -1.58940720e-03  6.73161200e-02
#  -1.72260620e-03  1.00278050e-02  2.25469900e-02 -5.75939270e-02
#   5.83565270e-02 -2.27362250e-02  2.66331360e-02 -3.19957470e-02
#  -2.92321880e-03  3.36862900e-02 -2.78159750e-02 -4.76991900e-02
#   1.40175640e-02 -1.18494900e-02 -8.63417000e-03  1.47142380e-02
#   2.57660450e-03  5.15863820e-02  3.74601300e-02 -1.22519120e-02
#   1.53519040e-02 -2.05861160e-02  1.71892640e-02  1.58632170e-02
#  -3.66574270e-02 -3.86620760e-02  2.11324730e-02 -7.72543300e-03
#  -2.26873530e-02  2.09903400e-02  2.51078770e-02  2.39826870e-02
#   2.69093480e-02 -6.78265840e-03  4.22699750e-02  3.87863900e-02
#  -7.09237300e-03  4.67878300e-02 -7.08892000e-02  5.21188080e-02
#   8.59320460e-02 -2.24075600e-02  1.95180510e-02  8.77947200e-04
#   1.78216910e-04 -4.50381340e-02  3.49699400e-02  5.27083540e-02
#  -3.32930900e-02 -4.60424420e-02 -4.44488640e-02 -1.84481240e-02
#  -4.39654700e-02 -5.99234230e-03  7.55060400e-05 -2.55379230e-02
#  -2.90182740e-02  3.38323300e-03  1.47234040e-02 -2.31828750e-02
#   1.60375810e-02 -4.54499650e-02 -4.16879950e-02  3.00030300e-03
#   7.19381800e-02 -1.67262650e-02 -1.46876300e-03 -2.12525270e-03
#  -2.92750320e-02 -4.10467600e-02  2.87772940e-02 -3.12514380e-02
#  -9.42116000e-02 -2.90343930e-02  2.51059510e-02  1.61699930e-02
#   1.75874680e-02  1.30391760e-02  6.84073100e-02  8.60981300e-03
#  -2.16336570e-02  1.24382395e-02  4.69973100e-03 -4.27862260e-02
#   3.19633900e-02  4.78549040e-02 -9.88335600e-03 -1.28722230e-02
#   4.83486880e-02 -3.99645530e-02 -7.54963230e-03 -1.06937270e-02
#  -2.61958800e-02 -3.49146400e-02  9.76727300e-03 -3.45070320e-02
#  -2.61900320e-03 -7.24357100e-02  1.94917860e-02 -2.87840890e-02
#  -5.13932500e-02 -3.81698800e-02 -6.71013960e-03 -2.50711220e-02
#  -1.61614830e-02  6.12520000e-02 -4.23506160e-02  1.37235260e-02
#   9.74603100e-03 -3.69592120e-02 -3.63900700e-02 -5.86726330e-02
#   4.97066160e-02 -1.24646180e-02 -2.33596450e-04 -1.75841670e-02
#  -1.17903175e-02  4.41097000e-02 -5.69168250e-03 -4.46758270e-02
#  -4.44925400e-03 -4.12238300e-02 -1.96054450e-02 -1.62213740e-02
#  -5.24653800e-02  4.93390930e-02 -4.71267250e-02 -1.72857300e-02
#   1.54073900e-02  2.16901950e-03  1.58600750e-02  6.20417950e-03
#  -3.01253180e-02  1.09499850e-02 -4.10861800e-03  3.16639840e-02
#  -4.60800400e-02  4.97216000e-02  1.85202750e-02 -1.66694380e-03
#  -3.73895020e-02 -2.83634810e-02 -8.66458800e-03  7.05965650e-03
#  -4.71710670e-02  2.49625740e-02  4.94333840e-02  3.74419540e-02
#  -1.88923380e-02 -1.44336450e-02  2.46392770e-02  7.34516900e-03
#   8.63649600e-02 -7.07504500e-02  2.34079730e-03  4.46535500e-02
#  -8.24224800e-03 -3.28782400e-02  3.26582380e-02  2.50031260e-02
#  -2.24598830e-02  2.03050170e-02  4.52756920e-02 -6.22434200e-02
#  -3.09675170e-02  2.74213520e-02  2.40131000e-02  8.58498200e-03
#   3.20216160e-02 -3.82795800e-02 -8.44797500e-02 -3.97441420e-02
#   5.06470540e-02 -3.10481270e-02 -9.58861700e-03 -2.60368830e-02
#  -2.78073180e-02  3.01907030e-02 -1.50479830e-02  3.41792480e-02
#  -6.58232300e-02 -2.05115140e-02  2.89597330e-02  1.08934790e-02
#   2.31852620e-02  1.93973260e-02  7.70056400e-03  1.31047910e-02
#   1.84685810e-02 -1.02737460e-02  1.92693830e-02  4.43460160e-02
#  -4.55572530e-02 -2.95784950e-03  3.17274760e-03 -6.55574200e-02
#   9.09376300e-03 -9.04758300e-03 -6.78058060e-03  5.01962640e-02
#   4.32386000e-02 -1.01186210e-02  4.37732100e-02 -4.30419900e-02
#   1.35767850e-02  1.61284490e-02 -1.25557390e-02 -2.95881520e-02
#  -1.15406870e-02  2.99325030e-02 -1.74297500e-02  3.18164560e-02
#   4.24034670e-02 -1.29115740e-02  1.46792130e-03 -2.12850200e-02
#   5.87258860e-02 -3.85196660e-02 -2.58603020e-02 -1.24541140e-02
#   7.82375200e-03  8.76064200e-03  4.35090920e-02 -5.50933850e-02
#  -3.24880100e-02 -1.72387350e-03 -3.36949750e-02 -1.61681910e-03
#   4.41129430e-02 -3.56248700e-02  1.31755420e-02  4.70128580e-02
#  -1.83322000e-02 -1.97420760e-03  7.40363700e-02  5.98493600e-02
#  -4.97819340e-03 -4.38648370e-03 -3.46440860e-02  4.13642500e-02
#  -4.21617370e-02 -3.38935200e-02 -8.54182150e-03 -2.06773750e-02
#   2.36476080e-02 -6.14181720e-02 -9.42070800e-03  2.80285480e-02
#   1.43656330e-02 -1.12983510e-02  2.67482250e-02 -2.74385080e-02
#   5.68037260e-02  3.48651100e-02  2.91911980e-02 -2.00261730e-03
#   5.68562080e-02  1.55450240e-02  1.68262630e-02 -3.35542340e-02
#   1.93974280e-02 -2.19165050e-02 -5.45280000e-02 -4.53151280e-02
#   6.06494840e-02  1.68334470e-02 -4.30429540e-02 -5.03760600e-02
#   3.04726140e-02  4.87671900e-02  3.53782550e-02 -1.75788160e-03
#   1.06267445e-02 -4.19187640e-03 -3.49957200e-02  3.66743950e-02
#   7.61259200e-02  2.13859060e-02  5.87828460e-02  5.00360170e-02
#  -2.46476900e-03  1.19827720e-02 -3.18231900e-02  3.00662740e-04
#  -3.83827700e-02  1.28980680e-02  1.87084860e-02 -1.29892010e-02
#  -5.54250200e-02 -7.49107450e-03  1.17533270e-02 -2.76906800e-03
#  -3.08971330e-02  3.98310300e-02  2.74818280e-02 -7.62976260e-02
#  -4.13866600e-02 -1.02543980e-02 -1.36975940e-02 -6.12642440e-04
#   1.85701030e-02 -7.60926200e-04  6.25954200e-02  2.82272320e-03
#  -3.62822380e-02  5.72624730e-04  4.20617000e-02 -1.79937130e-02
#  -3.49108700e-02  1.06199190e-02 -2.69890560e-02  1.07005160e-02
#  -4.73045300e-02 -2.45662460e-02 -2.46896740e-02 -5.59972150e-02
#  -3.20302800e-02  2.41739250e-02 -9.62316240e-02  2.82819220e-02
#   5.43381940e-02 -1.42173260e-02  3.64129540e-02  2.11348270e-02
#  -1.32589130e-02  4.47046270e-02  2.38819140e-02  7.21296440e-03
#   8.25403000e-03 -2.29417100e-02 -3.03075180e-02 -5.39677030e-03
#  -3.36933900e-02  6.32150900e-02  4.97667040e-02  6.06256720e-03
#  -4.19392200e-02 -3.78090740e-02  5.77954200e-03 -1.13874180e-02
#   2.65390690e-02  5.00961170e-02  1.65162830e-02 -2.07435130e-03
#  -3.98416860e-03 -2.54988910e-02  4.16852760e-02  3.80008400e-02
#  -3.45335100e-02 -4.53874500e-02 -1.69561020e-02  1.44807110e-02
#   2.62253860e-02  2.00257660e-02  4.07098900e-03  4.64413280e-02
#   3.94717340e-02  5.21201680e-02  3.68373770e-02 -3.76561320e-02
#  -2.89826060e-02  3.29162660e-02  8.94200150e-03 -4.91933800e-02
#  -9.82069900e-04  2.31448520e-02 -2.12004690e-02  4.85240800e-02
#  -2.56807050e-03  4.93992600e-02  2.44277100e-02 -7.39542670e-03
#  -6.39230700e-02  7.49275460e-02 -4.84953560e-02 -1.98706400e-02
#  -1.23828240e-02  1.34750440e-02  6.74573400e-02 -3.33924930e-02
#  -2.74777300e-02  1.84742060e-02 -3.87788380e-02  7.55637500e-02
#   2.96052560e-02  2.82198340e-02 -1.71154220e-02 -8.21052800e-02
#  -7.27581100e-03 -2.55749820e-03  5.13224350e-03  5.80404700e-02
#   1.22969710e-02  9.29981240e-04 -1.28311740e-02 -5.51930630e-02
#  -3.47290680e-03 -5.28665450e-02 -2.17222310e-02  6.10186860e-03
#  -3.94705300e-02  8.03263400e-02  5.32568730e-02 -3.38522270e-02
#   2.09190030e-02 -2.43992360e-03 -6.93678670e-03  2.80817800e-02
#  -2.95396500e-02 -2.39160600e-04  3.05834620e-03 -2.32241210e-02
#   4.85296100e-02  2.96115320e-02 -2.84509980e-02  2.21803150e-02]
# --------------------------------------------------

# %% [markdown]
# # **RAG**

# %% [markdown]
# Nous allons utliser l'embeding de mistral pour la suite

# %%
# Créer une instance du RAG avec le modèle d'embedding et le magasin de vecteurs
rag_retriever = RagRetriever(modele_embedding=embedding_gemini, magasin_vecteurs=vector_store)

# %%
# Ajouter des documents au magasin de vecteurs via le RAG sur l'education nationale de la France
documents = [
    "L'éducation nationale est un service public chargé de l'éducation en France.",
    "Les enseignants sont des professionnels de l'éducation.",
    "Les élèves apprennent des matières variées à l'école."
]

metadonnees = [ {"theme": "Education", "categorie": "Service public"},
                {"theme": "Education", "categorie": "Profession"},
                {"theme": "Education", "categorie": "Scolarité"}]
await rag_retriever.ajouter_documents(documents, metadonnees)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 11
#       2 documents = [
#       3     "L'éducation nationale est un service public chargé de l'éducation en France.",
#       4     "Les enseignants sont des professionnels de l'éducation.",
#       5     "Les élèves apprennent des matières variées à l'école."
#       6 ]
#       8 metadonnees = [ {"theme": "Education", "categorie": "Service public"},
#       9                 {"theme": "Education", "categorie": "Profession"},
#      10                 {"theme": "Education", "categorie": "Scolarité"}]
# ---> 11 await rag_retriever.ajouter_documents(documents, metadonnees)
#
# File c:\Users\lcisse\Desktop\pM2SISE\llm\rag\rag_retriever.py:38, in RagRetriever.ajouter_documents(self, textes, metadonnees)
#      36 # Vérification si la méthode existe dans l'embedder
#      37 embeddings = await self.modele_embedding.embed_batch(textes)  # Ou générer_embeddings_lot si c'est le nom de la méthode
# ---> 38 self.magasin_vecteurs.ajouter_documents(textes, embeddings, metadonnees)
#
# TypeError: VectorStore.ajouter_documents() takes from 2 to 3 positional arguments but 4 were given

# %%
# Rechercher des documents pertinents pour une requête
requete_rag = "Parle-moi de la relativité restreinte."
resultats_rag = await rag_retriever.recuperer_documents_avec_scores(requete_rag)
print("Documents trouvés avec scores :", resultats_rag)

# %% [markdown]
# # **LLM**

# %%
# Initialiser le modèle LLM (Mistral comme exemple)
# Instanciation de la classe MultiModelLLM
llm = MultiModelLLM(
    api_key_mistral=MISTRAL_API_KEY,
    api_key_gemini=GEMINI_API_KEY,
    default_model="large",
    default_provider="mistral"
)

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
# Génération avec le fournisseur Mistral
response_mistral = await llm.generate(
    prompt="Expliquez la théorie de la relativité en termes simples.",
    provider="mistral",
    model="Mistral-Small-Instruct-2409",
    temperature=0.7,
    max_tokens=150
)
print("Réponse de Mistral:")
print(response_mistral)
# Out:
# INFO:httpx:HTTP Request: POST https://api.mistral.ai/v1/chat/completions "HTTP/1.1 400 Bad Request"
# ERROR:llm.models.model_api:Mistral API error: API error occurred: Status 400
# {"object":"error","message":"Invalid model: Mistral-Small-Instruct-2409","type":"invalid_model","param":null,"code":"1500"}
# Réponse de Mistral:
# Mistral API Error: API error occurred: Status 400
# {"object":"error","message":"Invalid model: Mistral-Small-Instruct-2409","type":"invalid_model","param":null,"code":"1500"}

# %% [markdown]
# Il faut trouver le bon nom de modèle et de fournisseur pour utiliser le modèle de mistral

# %%
# Génération avec le fournisseur Gemini
prompt_gemini = "Quels sont les principaux avantages de l'utilisation de modèles de langage avancés ?"
response_gemini = await llm.generate(
    prompt=prompt_gemini,
    provider="gemini",
    model="gemini-1.5-flash",
    temperature=0.7,
    max_tokens=10000
)
print("\nRéponse de Gemini:")
print(response_gemini)
# Out:
# Réponse de Gemini:
# Les modèles de langage avancés, comme GPT-3 et ses successeurs, offrent de nombreux avantages, notamment :
#
# **Pour les utilisateurs finaux:**
#
# * **Accès à l'information et génération de contenu facilités:**  Ils permettent de générer du texte de manière rapide et efficace pour diverses tâches, comme la rédaction d'e-mails, de résumés, d'articles, de poèmes, de code, etc.  L'accès à l'information est facilité grâce à leur capacité à synthétiser des données provenant de vastes corpus de texte.
# * **Personnalisation accrue:** Ils peuvent adapter leur style et leur ton en fonction du contexte et des besoins de l'utilisateur, offrant une expérience plus personnalisée.
# * **Traitement du langage naturel amélioré:**  Ils comprennent mieux le langage humain, permettant des interactions plus naturelles et fluides avec les machines.  Cela est utile pour les chatbots, les assistants virtuels et les systèmes de recherche d'information.
# * **Traduction automatique plus précise:**  Ils améliorent la qualité des traductions automatiques, permettant une communication plus efficace entre les cultures.
# * **Accessibilité améliorée:** Ils peuvent aider les personnes ayant des difficultés à écrire ou à communiquer à exprimer leurs idées.
#
#
# **Pour les entreprises et les développeurs:**
#
# * **Automatisation des tâches:**  Ils permettent d'automatiser de nombreuses tâches fastidieuses et répétitives liées au traitement du langage naturel, comme l'analyse de sentiment, la classification de texte et l'extraction d'informations.
# * **Amélioration de l'efficacité:**  Ils accélèrent les processus de travail et augmentent la productivité.
# * **Création de nouvelles applications et services:**  Ils ouvrent la voie à la création de nouvelles applications innovantes dans divers domaines, tels que la santé, l'éducation, le commerce électronique et le divertissement.
# * **Analyse de données approfondie:**  Ils permettent d'analyser de grandes quantités de données textuelles pour en extraire des informations précieuses et des tendances.
# * **Personnalisation de l'expérience client:**  Ils permettent de créer des expériences client plus personnalisées et engageantes.
#
#
# **Cependant, il est important de noter les limitations:**
#
# * **Biais et toxicité:**  Les modèles de langage sont entraînés sur des données qui peuvent contenir des biais, ce qui peut entraîner la génération de contenu biaisé ou toxique.
# * **Manque de compréhension du monde réel:**  Ils peuvent générer du texte qui semble plausible mais qui est factuellement incorrect ou dénué de sens.
# * **Consommation de ressources:**  L'entraînement et l'utilisation de ces modèles nécessitent des ressources informatiques importantes.
# * **Problèmes éthiques:**  L'utilisation de ces modèles soulève des questions éthiques concernant la confidentialité, la désinformation et l'utilisation abusive.
#
#
# En résumé, les modèles de langage avancés offrent un potentiel immense, mais leur utilisation doit être encadrée par une prise de conscience de leurs limites et des implications éthiques.

# %%
# Changer dynamiquement de fournisseur et modèle
llm.switch_provider(new_provider="gemini", new_model_name="gemini-1.5-pro")
prompt_switch = "Explique-moi les bases de l'apprentissage profond."
response_switch = await llm.generate(
    prompt=prompt_switch,
    temperature=0.5,
    max_tokens=1500
)
print("\nRéponse après changement de fournisseur et de modèle:")
print(response_switch)
# Out:
# INFO:llm.models.model_api:Switching provider to gemini with model gemini-1.5-pro
# Réponse après changement de fournisseur et de modèle:
# L'apprentissage profond (Deep Learning) est un sous-domaine de l'apprentissage automatique (Machine Learning) qui utilise des réseaux de neurones artificiels avec plusieurs couches (d'où le terme "profond") pour extraire des caractéristiques de données complexes et apprendre des représentations hiérarchiques.  Imaginez une pyramide : les couches inférieures apprennent des caractéristiques simples, tandis que les couches supérieures combinent ces caractéristiques pour apprendre des concepts plus abstraits et complexes.
#
# Voici les bases clés :
#
# **1. Réseaux de neurones artificiels (RNA) :**  L'élément fondamental de l'apprentissage profond.  Un RNA est un modèle inspiré du cerveau humain, composé de nœuds (neurones) interconnectés organisés en couches :
#
# * **Couche d'entrée (Input Layer):** Reçoit les données d'entrée (ex: pixels d'une image, mots d'un texte).
# * **Couches cachées (Hidden Layers):**  Plusieurs couches intermédiaires qui effectuent des transformations non-linéaires des données.  C'est ici que l'apprentissage profond se distingue de l'apprentissage automatique "classique" : plus il y a de couches cachées, plus le réseau est profond et capable d'apprendre des représentations complexes.
# * **Couche de sortie (Output Layer):** Produit la sortie du réseau (ex: classification d'une image, traduction d'une phrase).
#
# Chaque connexion entre les neurones a un poids associé, qui représente la force de la connexion.  Le processus d'apprentissage consiste à ajuster ces poids pour minimiser l'erreur entre la sortie du réseau et la sortie attendue.
#
# **2. Apprentissage supervisé, non supervisé et par renforcement :** L'apprentissage profond peut utiliser différents paradigmes d'apprentissage :
#
# * **Apprentissage supervisé:** Le réseau est entraîné sur un ensemble de données étiquetées (ex: images de chats étiquetées comme "chat").  Le but est d'apprendre à prédire correctement les étiquettes pour de nouvelles données.
# * **Apprentissage non supervisé:** Le réseau est entraîné sur un ensemble de données non étiquetées.  Le but est de découvrir des structures et des modèles cachés dans les données (ex: regroupement d'images similaires).
# * **Apprentissage par renforcement:** Le réseau apprend par interaction avec un environnement.  Il reçoit des récompenses ou des pénalités en fonction de ses actions, et ajuste ses poids pour maximiser sa récompense cumulative (ex: jeux vidéo, robotique).
#
# **3. Propagation avant (Forward Propagation) et rétropropagation (Backpropagation):**
#
# * **Propagation avant:**  Les données d'entrée sont propagées à travers le réseau, de la couche d'entrée à la couche de sortie, en calculant les activations de chaque neurone.
# * **Rétropropagation:**  L'erreur entre la sortie du réseau et la sortie attendue est calculée.  Cette erreur est ensuite propagée en arrière à travers le réseau, permettant d'ajuster les poids des connexions pour réduire l'erreur.  C'est un processus itératif qui se répète jusqu'à ce que l'erreur soit minimisée.
#
# **4. Fonctions d'activation:**  Chaque neurone applique une fonction d'activation à sa somme pondérée d'entrées.  Ces fonctions introduisent de la non-linéarité dans le réseau, permettant d'apprendre des représentations plus complexes.  Des exemples incluent ReLU (Rectified Linear Unit), sigmoid et tanh.
#
# **5. Optimisation:**  Des algorithmes d'optimisation, comme l'algorithme de descente de gradient, sont utilisés pour ajuster les poids du réseau afin de minimiser la fonction de coût (qui mesure l'erreur).
#
# **En résumé:** L'apprentissage profond utilise des réseaux de neurones profonds pour apprendre des représentations hiérarchiques de données complexes.  Il repose sur la propagation avant et la rétropropagation pour ajuster les poids du réseau et minimiser l'erreur.  Différents paradigmes d'apprentissage peuvent être utilisés, et le choix de l'architecture du réseau et des hyperparamètres est crucial pour la performance du modèle.  C'est un domaine en constante évolution avec de nouvelles architectures et techniques qui émergent régulièrement.
